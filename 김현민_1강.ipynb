# %% [markdown]
# <a href="https://colab.research.google.com/github/1801310khm/knu_bdna_2022/blob/main/%EA%B9%80%ED%98%84%EB%AF%BC_1%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("hello world")

# %%
def greet2(name):
  print('반갑습니다',name)
  print(name,'님은 파이썬의 세계로 오셨습니다')

# %%
greet2('김현민')
# Out:
# 반갑습니다 김현민
# 김현민 님은 파이썬의 세계로 오셨습니다

# %%
def adder(num1,num2):
  sum=num1+num2
  print('덧셈 결과:',num1+num2)

# %%
adder(10,5)
# Out:
# 덧셈 결과: 15

# %%
def adder(num1,num2):
  sum = num1+num2
  return sum

# %%
result = adder(10,5)

# %%
print(sum)
# Out:
# <built-in function sum>

# %%
result = eval(input("뭐든 넣어요"))
# Out:
# 뭐든 넣어요445+11*3/4

# %%
result
# Out:
# 453.25

# %%
def greet_10(num):
  if (num>0):
    print('hi')
    num=num-1
    greet_10(num)

# %%
greet_10(3)
# Out:
# hi
# hi
# hi

# %%
sum=0
for i in range(1,11):
  sum=sum+i

# %%
import random

NUMBER_OF_TRIALS=5000000#상수
numberOfHits=0
for i in range(NUMBER_OF_TRIALS):
   x= random.random()* 2-1
   y= random.random()* 2-1
   if x*x+y*y<=1:
    numberOfHits+=1
    pi=4*numberOfHits/NUMBER_OF_TRIALS
    print("PI는",pi,"입니다.")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# PI는 0.0748496 입니다.
# PI는 0.0748504 입니다.
# PI는 0.0748512 입니다.
# PI는 0.074852 입니다.
# PI는 0.0748528 입니다.
# PI는 0.0748536 입니다.
# PI는 0.0748544 입니다.
# PI는 0.0748552 입니다.
# PI는 0.074856 입니다.
# PI는 0.0748568 입니다.
# PI는 0.0748576 입니다.
# PI는 0.0748584 입니다.
# PI는 0.0748592 입니다.
# PI는 0.07486 입니다.
# PI는 0.0748608 입니다.
# PI는 0.0748616 입니다.
# PI는 0.0748624 입니다.
# PI는 0.0748632 입니다.
# PI는 0.074864 입니다.
# PI는 0.0748648 입니다.
# PI는 0.0748656 입니다.
# PI는 0.0748664 입니다.
# PI는 0.0748672 입니다.
# PI는 0.074868 입니다.
# PI는 0.0748688 입니다.
# PI는 0.0748696 입니다.
# PI는 0.0748704 입니다.
# PI는 0.0748712 입니다.
# PI는 0.074872 입니다.
# PI는 0.0748728 입니다.
# PI는 0.0748736 입니다.
# PI는 0.0748744 입니다.
# PI는 0.0748752 입니다.
# PI는 0.074876 입니다.
# PI는 0.0748768 입니다.
# PI는 0.0748776 입니다.
# PI는 0.0748784 입니다.
# PI는 0.0748792 입니다.
# PI는 0.07488 입니다.
# PI는 0.0748808 입니다.
# PI는 0.0748816 입니다.
# PI는 0.0748824 입니다.
# PI는 0.0748832 입니다.
# PI는 0.074884 입니다.
# PI는 0.0748848 입니다.
# PI는 0.0748856 입니다.
# PI는 0.0748864 입니다.
# PI는 0.0748872 입니다.
# PI는 0.074888 입니다.
# PI는 0.0748888 입니다.
# PI는 0.0748896 입니다.
# PI는 0.0748904 입니다.
# PI는 0.0748912 입니다.
# PI는 0.074892 입니다.
# PI는 0.0748928 입니다.
# PI는 0.0748936 입니다.
# PI는 0.0748944 입니다.
# PI는 0.0748952 입니다.
# PI는 0.074896 입니다.
# PI는 0.0748968 입니다.
# PI는 0.0748976 입니다.
# PI는 0.0748984 입니다.
# PI는 0.0748992 입니다.
# PI는 0.0749 입니다.
# PI는 0.0749008 입니다.
# PI는 0.0749016 입니다.
# PI는 0.0749024 입니다.
# PI는 0.0749032 입니다.
# PI는 0.074904 입니다.
# PI는 0.0749048 입니다.
# PI는 0.0749056 입니다.
# PI는 0.0749064 입니다.
# PI는 0.0749072 입니다.
# PI는 0.074908 입니다.
# PI는 0.0749088 입니다.
# PI는 0.0749096 입니다.
# PI는 0.0749104 입니다.
# PI는 0.0749112 입니다.
# PI는 0.074912 입니다.
# PI는 0.0749128 입니다.
# PI는 0.0749136 입니다.
# PI는 0.0749144 입니다.
# PI는 0.0749152 입니다.
# PI는 0.074916 입니다.
# PI는 0.0749168 입니다.
# PI는 0.0749176 입니다.
# PI는 0.0749184 입니다.
# PI는 0.0749192 입니다.
# PI는 0.07492 입니다.
# PI는 0.0749208 입니다.
# PI는 0.0749216 입니다.
# PI는 0.0749224 입니다.
# PI는 0.0749232 입니다.
# PI는 0.074924 입니다.
# PI는 0.0749248 입니다.
# PI는 0.0749256 입니다.
# PI는 0.0749264 입니다.
# PI는 0.0749272 입니다.
# PI는 0.074928 입니다.
# PI는 0.0749288 입니다.
# PI는 0.0749296 입니다.
# PI는 0.0749304 입니다.
# PI는 0.0749312 입니다.
# PI는 0.074932 입니다.
# PI는 0.0749328 입니다.
# PI는 0.0749336 입니다.
# PI는 0.0749344 입니다.
# PI는 0.0749352 입니다.
# PI는 0.074936 입니다.
# PI는 0.0749368 입니다.
# PI는 0.0749376 입니다.
# PI는 0.0749384 입니다.
# PI는 0.0749392 입니다.
# PI는 0.07494 입니다.
# PI는 0.0749408 입니다.
# PI는 0.0749416 입니다.
# PI는 0.0749424 입니다.
# PI는 0.0749432 입니다.
# PI는 0.074944 입니다.
# PI는 0.0749448 입니다.
# PI는 0.0749456 입니다.
# PI는 0.0749464 입니다.
# PI는 0.0749472 입니다.
# PI는 0.074948 입니다.
# PI는 0.0749488 입니다.
# PI는 0.0749496 입니다.
# PI는 0.0749504 입니다.
# PI는 0.0749512 입니다.
# PI는 0.074952 입니다.
# PI는 0.0749528 입니다.
# PI는 0.0749536 입니다.
# PI는 0.0749544 입니다.
# PI는 0.0749552 입니다.
# PI는 0.074956 입니다.
# PI는 0.0749568 입니다.
# PI는 0.0749576 입니다.
# PI는 0.0749584 입니다.
# PI는 0.0749592 입니다.
# PI는 0.07496 입니다.
# PI는 0.0749608 입니다.
# PI는 0.0749616 입니다.
# PI는 0.0749624 입니다.
# PI는 0.0749632 입니다.
# PI는 0.074964 입니다.
# PI는 0.0749648 입니다.
# PI는 0.0749656 입니다.
# PI는 0.0749664 입니다.
# PI는 0.0749672 입니다.
# PI는 0.074968 입니다.
# PI는 0.0749688 입니다.
# PI는 0.0749696 입니다.
# PI는 0.0749704 입니다.
# PI는 0.0749712 입니다.
# PI는 0.074972 입니다.
# PI는 0.0749728 입니다.
# PI는 0.0749736 입니다.
# PI는 0.0749744 입니다.
# PI는 0.0749752 입니다.
# PI는 0.074976 입니다.
# PI는 0.0749768 입니다.
# PI는 0.0749776 입니다.
# PI는 0.0749784 입니다.
# PI는 0.0749792 입니다.
# PI는 0.07498 입니다.
# PI는 0.0749808 입니다.
# PI는 0.0749816 입니다.
# PI는 0.0749824 입니다.
# PI는 0.0749832 입니다.
# PI는 0.074984 입니다.
# PI는 0.0749848 입니다.
# PI는 0.0749856 입니다.
# PI는 0.0749864 입니다.
# PI는 0.0749872 입니다.
# PI는 0.074988 입니다.
# PI는 0.0749888 입니다.
# PI는 0.0749896 입니다.
# PI는 0.0749904 입니다.
# PI는 0.0749912 입니다.
# PI는 0.074992 입니다.
# PI는 0.0749928 입니다.
# PI는 0.0749936 입니다.
# PI는 0.0749944 입니다.
# PI는 0.0749952 입니다.
# PI는 0.074996 입니다.
# PI는 0.0749968 입니다.
# PI는 0.0749976 입니다.
# PI는 0.0749984 입니다.
# PI는 0.0749992 입니다.
# PI는 0.075 입니다.
# PI는 0.0750008 입니다.
# PI는 0.0750016 입니다.
# PI는 0.0750024 입니다.
# PI는 0.0750032 입니다.
# PI는 0.075004 입니다.
# PI는 0.0750048 입니다.
# PI는 0.0750056 입니다.
# PI는 0.0750064 입니다.
# PI는 0.0750072 입니다.
# PI는 0.075008 입니다.
# PI는 0.0750088 입니다.
# PI는 0.0750096 입니다.
# PI는 0.0750104 입니다.
# PI는 0.0750112 입니다.
# PI는 0.075012 입니다.
# PI는 0.0750128 입니다.
# PI는 0.0750136 입니다.
# PI는 0.0750144 입니다.
# PI는 0.0750152 입니다.
# PI는 0.075016 입니다.
# PI는 0.0750168 입니다.
# PI는 0.0750176 입니다.
# PI는 0.0750184 입니다.
# PI는 0.0750192 입니다.
# PI는 0.07502 입니다.
# PI는 0.0750208 입니다.
# PI는 0.0750216 입니다.
# PI는 0.0750224 입니다.
# PI는 0.0750232 입니다.
# PI는 0.075024 입니다.
# PI는 0.0750248 입니다.
# PI는 0.0750256 입니다.
# PI는 0.0750264 입니다.
# PI는 0.0750272 입니다.
# PI는 0.075028 입니다.
# PI는 0.0750288 입니다.
# PI는 0.0750296 입니다.
# PI는 0.0750304 입니다.
# PI는 0.0750312 입니다.
# PI는 0.075032 입니다.
# PI는 0.0750328 입니다.
# PI는 0.0750336 입니다.
# PI는 0.0750344 입니다.
# PI는 0.0750352 입니다.
# PI는 0.075036 입니다.
# PI는 0.0750368 입니다.
# PI는 0.0750376 입니다.
# PI는 0.0750384 입니다.
# PI는 0.0750392 입니다.
# PI는 0.07504 입니다.
# PI는 0.0750408 입니다.
# PI는 0.0750416 입니다.
# PI는 0.0750424 입니다.
# PI는 0.0750432 입니다.
# PI는 0.075044 입니다.
# PI는 0.0750448 입니다.
# PI는 0.0750456 입니다.
# PI는 0.0750464 입니다.
# PI는 0.0750472 입니다.
# PI는 0.075048 입니다.
# PI는 0.0750488 입니다.
# PI는 0.0750496 입니다.
# PI는 0.0750504 입니다.
# PI는 0.0750512 입니다.
# PI는 0.075052 입니다.
# PI는 0.0750528 입니다.
# PI는 0.0750536 입니다.
# PI는 0.0750544 입니다.
# PI는 0.0750552 입니다.
# PI는 0.075056 입니다.
# PI는 0.0750568 입니다.
# PI는 0.0750576 입니다.
# PI는 0.0750584 입니다.
# PI는 0.0750592 입니다.
# PI는 0.07506 입니다.
# PI는 0.0750608 입니다.
# PI는 0.0750616 입니다.
# PI는 0.0750624 입니다.
# PI는 0.0750632 입니다.
# PI는 0.075064 입니다.
# PI는 0.0750648 입니다.
# PI는 0.0750656 입니다.
# PI는 0.0750664 입니다.
# PI는 0.0750672 입니다.
# PI는 0.075068 입니다.
# PI는 0.0750688 입니다.
# PI는 0.0750696 입니다.
# PI는 0.0750704 입니다.
# PI는 0.0750712 입니다.
# PI는 0.075072 입니다.
# PI는 0.0750728 입니다.
# PI는 0.0750736 입니다.
# PI는 0.0750744 입니다.
# PI는 0.0750752 입니다.
# PI는 0.075076 입니다.
# PI는 0.0750768 입니다.
# PI는 0.0750776 입니다.
# PI는 0.0750784 입니다.
# PI는 0.0750792 입니다.
# PI는 0.07508 입니다.
# PI는 0.0750808 입니다.
# PI는 0.0750816 입니다.
# PI는 0.0750824 입니다.
# PI는 0.0750832 입니다.
# PI는 0.075084 입니다.
# PI는 0.0750848 입니다.
# PI는 0.0750856 입니다.
# PI는 0.0750864 입니다.
# PI는 0.0750872 입니다.
# PI는 0.075088 입니다.
# PI는 0.0750888 입니다.
# PI는 0.0750896 입니다.
# PI는 0.0750904 입니다.
# PI는 0.0750912 입니다.
# PI는 0.075092 입니다.
# PI는 0.0750928 입니다.
# PI는 0.0750936 입니다.
# PI는 0.0750944 입니다.
# PI는 0.0750952 입니다.
# PI는 0.075096 입니다.
# PI는 0.0750968 입니다.
# PI는 0.0750976 입니다.
# PI는 0.0750984 입니다.
# PI는 0.0750992 입니다.
# PI는 0.0751 입니다.
# PI는 0.0751008 입니다.
# PI는 0.0751016 입니다.
# PI는 0.0751024 입니다.
# PI는 0.0751032 입니다.
# PI는 0.075104 입니다.
# PI는 0.0751048 입니다.
# PI는 0.0751056 입니다.
# PI는 0.0751064 입니다.
# PI는 0.0751072 입니다.
# PI는 0.075108 입니다.
# PI는 0.0751088 입니다.
# PI는 0.0751096 입니다.
# PI는 0.0751104 입니다.
# PI는 0.0751112 입니다.
# PI는 0.075112 입니다.
# PI는 0.0751128 입니다.
# PI는 0.0751136 입니다.
# PI는 0.0751144 입니다.
# PI는 0.0751152 입니다.
# PI는 0.075116 입니다.
# PI는 0.0751168 입니다.
# PI는 0.0751176 입니다.
# PI는 0.0751184 입니다.
# PI는 0.0751192 입니다.
# PI는 0.07512 입니다.
# PI는 0.0751208 입니다.
# PI는 0.0751216 입니다.
# PI는 0.0751224 입니다.
# PI는 0.0751232 입니다.
# PI는 0.075124 입니다.
# PI는 0.0751248 입니다.
# PI는 0.0751256 입니다.
# PI는 0.0751264 입니다.
# PI는 0.0751272 입니다.
# PI는 0.075128 입니다.
# PI는 0.0751288 입니다.
# PI는 0.0751296 입니다.
# PI는 0.0751304 입니다.
# PI는 0.0751312 입니다.
# PI는 0.075132 입니다.
# PI는 0.0751328 입니다.
# PI는 0.0751336 입니다.
# PI는 0.0751344 입니다.
# PI는 0.0751352 입니다.
# PI는 0.075136 입니다.
# PI는 0.0751368 입니다.
# PI는 0.0751376 입니다.
# PI는 0.0751384 입니다.
# PI는 0.0751392 입니다.
# PI는 0.07514 입니다.
# PI는 0.0751408 입니다.
# PI는 0.0751416 입니다.
# PI는 0.0751424 입니다.
# PI는 0.0751432 입니다.
# PI는 0.075144 입니다.
# PI는 0.0751448 입니다.
# PI는 0.0751456 입니다.
# PI는 0.0751464 입니다.
# PI는 0.0751472 입니다.
# PI는 0.075148 입니다.
# PI는 0.0751488 입니다.
# PI는 0.0751496 입니다.
# PI는 0.0751504 입니다.
# PI는 0.0751512 입니다.
# PI는 0.075152 입니다.
# PI는 0.0751528 입니다.
# PI는 0.0751536 입니다.
# PI는 0.0751544 입니다.
# PI는 0.0751552 입니다.
# PI는 0.075156 입니다.
# PI는 0.0751568 입니다.
# PI는 0.0751576 입니다.
# PI는 0.0751584 입니다.
# PI는 0.0751592 입니다.
# PI는 0.07516 입니다.
# PI는 0.0751608 입니다.
# PI는 0.0751616 입니다.
# PI는 0.0751624 입니다.
# PI는 0.0751632 입니다.
# PI는 0.075164 입니다.
# PI는 0.0751648 입니다.
# PI는 0.0751656 입니다.
# PI는 0.0751664 입니다.
# PI는 0.0751672 입니다.
# PI는 0.075168 입니다.
# PI는 0.0751688 입니다.
# PI는 0.0751696 입니다.
# PI는 0.0751704 입니다.
# PI는 0.0751712 입니다.
# PI는 0.075172 입니다.
# PI는 0.0751728 입니다.
# PI는 0.0751736 입니다.
# PI는 0.0751744 입니다.
# PI는 0.0751752 입니다.
# PI는 0.075176 입니다.
# PI는 0.0751768 입니다.
# PI는 0.0751776 입니다.
# PI는 0.0751784 입니다.
# PI는 0.0751792 입니다.
# PI는 0.07518 입니다.
# PI는 0.0751808 입니다.
# PI는 0.0751816 입니다.
# PI는 0.0751824 입니다.
# PI는 0.0751832 입니다.
# PI는 0.075184 입니다.
# PI는 0.0751848 입니다.
# PI는 0.0751856 입니다.
# PI는 0.0751864 입니다.
# PI는 0.0751872 입니다.
# PI는 0.075188 입니다.
# PI는 0.0751888 입니다.
# PI는 0.0751896 입니다.
# PI는 0.0751904 입니다.
# PI는 0.0751912 입니다.
# PI는 0.075192 입니다.
# PI는 0.0751928 입니다.
# PI는 0.0751936 입니다.
# PI는 0.0751944 입니다.
# PI는 0.0751952 입니다.
# PI는 0.075196 입니다.
# PI는 0.0751968 입니다.
# PI는 0.0751976 입니다.
# PI는 0.0751984 입니다.
# PI는 0.0751992 입니다.
# PI는 0.0752 입니다.
# PI는 0.0752008 입니다.
# PI는 0.0752016 입니다.
# PI는 0.0752024 입니다.
# PI는 0.0752032 입니다.
# PI는 0.075204 입니다.
# PI는 0.0752048 입니다.
# PI는 0.0752056 입니다.
# PI는 0.0752064 입니다.
# PI는 0.0752072 입니다.
# PI는 0.075208 입니다.
# PI는 0.0752088 입니다.
# PI는 0.0752096 입니다.
# PI는 0.0752104 입니다.
# PI는 0.0752112 입니다.
# PI는 0.075212 입니다.
# PI는 0.0752128 입니다.
# PI는 0.0752136 입니다.
# PI는 0.0752144 입니다.
# PI는 0.0752152 입니다.
# PI는 0.075216 입니다.
# PI는 0.0752168 입니다.
# PI는 0.0752176 입니다.
# PI는 0.0752184 입니다.
# PI는 0.0752192 입니다.
# PI는 0.07522 입니다.
# PI는 0.0752208 입니다.
# PI는 0.0752216 입니다.
# PI는 0.0752224 입니다.
# PI는 0.0752232 입니다.
# PI는 0.075224 입니다.
# PI는 0.0752248 입니다.
# PI는 0.0752256 입니다.
# PI는 0.0752264 입니다.
# PI는 0.0752272 입니다.
# PI는 0.075228 입니다.
# PI는 0.0752288 입니다.
# PI는 0.0752296 입니다.
# PI는 0.0752304 입니다.
# PI는 0.0752312 입니다.
# PI는 0.075232 입니다.
# PI는 0.0752328 입니다.
# PI는 0.0752336 입니다.
# PI는 0.0752344 입니다.
# PI는 0.0752352 입니다.
# PI는 0.075236 입니다.
# PI는 0.0752368 입니다.
# PI는 0.0752376 입니다.
# PI는 0.0752384 입니다.
# PI는 0.0752392 입니다.
# PI는 0.07524 입니다.
# PI는 0.0752408 입니다.
# PI는 0.0752416 입니다.
# PI는 0.0752424 입니다.
# PI는 0.0752432 입니다.
# PI는 0.075244 입니다.
# PI는 0.0752448 입니다.
# PI는 0.0752456 입니다.
# PI는 0.0752464 입니다.
# PI는 0.0752472 입니다.
# PI는 0.075248 입니다.
# PI는 0.0752488 입니다.
# PI는 0.0752496 입니다.
# PI는 0.0752504 입니다.
# PI는 0.0752512 입니다.
# PI는 0.075252 입니다.
# PI는 0.0752528 입니다.
# PI는 0.0752536 입니다.
# PI는 0.0752544 입니다.
# PI는 0.0752552 입니다.
# PI는 0.075256 입니다.
# PI는 0.0752568 입니다.
# PI는 0.0752576 입니다.
# PI는 0.0752584 입니다.
# PI는 0.0752592 입니다.
# PI는 0.07526 입니다.
# PI는 0.0752608 입니다.
# PI는 0.0752616 입니다.
# PI는 0.0752624 입니다.
# PI는 0.0752632 입니다.
# PI는 0.075264 입니다.
# PI는 0.0752648 입니다.
# PI는 0.0752656 입니다.
# PI는 0.0752664 입니다.
# PI는 0.0752672 입니다.
# PI는 0.075268 입니다.
# PI는 0.0752688 입니다.
# PI는 0.0752696 입니다.
# PI는 0.0752704 입니다.
# PI는 0.0752712 입니다.
# PI는 0.075272 입니다.
# PI는 0.0752728 입니다.
# PI는 0.0752736 입니다.
# PI는 0.0752744 입니다.
# PI는 0.0752752 입니다.
# PI는 0.075276 입니다.
# PI는 0.0752768 입니다.
# PI는 0.0752776 입니다.
# PI는 0.0752784 입니다.
# PI는 0.0752792 입니다.
# PI는 0.07528 입니다.
# PI는 0.0752808 입니다.
# PI는 0.0752816 입니다.
# PI는 0.0752824 입니다.
# PI는 0.0752832 입니다.
# PI는 0.075284 입니다.
# PI는 0.0752848 입니다.
# PI는 0.0752856 입니다.
# PI는 0.0752864 입니다.
# PI는 0.0752872 입니다.
# PI는 0.075288 입니다.
# PI는 0.0752888 입니다.
# PI는 0.0752896 입니다.
# PI는 0.0752904 입니다.
# PI는 0.0752912 입니다.
# PI는 0.075292 입니다.
# PI는 0.0752928 입니다.
# PI는 0.0752936 입니다.
# PI는 0.0752944 입니다.
# PI는 0.0752952 입니다.
# PI는 0.075296 입니다.
# PI는 0.0752968 입니다.
# PI는 0.0752976 입니다.
# PI는 0.0752984 입니다.
# PI는 0.0752992 입니다.
# PI는 0.0753 입니다.
# PI는 0.0753008 입니다.
# PI는 0.0753016 입니다.
# PI는 0.0753024 입니다.
# PI는 0.0753032 입니다.
# PI는 0.075304 입니다.
# PI는 0.0753048 입니다.
# PI는 0.0753056 입니다.
# PI는 0.0753064 입니다.
# PI는 0.0753072 입니다.
# PI는 0.075308 입니다.
# PI는 0.0753088 입니다.
# PI는 0.0753096 입니다.
# PI는 0.0753104 입니다.
# PI는 0.0753112 입니다.
# PI는 0.075312 입니다.
# PI는 0.0753128 입니다.
# PI는 0.0753136 입니다.
# PI는 0.0753144 입니다.
# PI는 0.0753152 입니다.
# PI는 0.075316 입니다.
# PI는 0.0753168 입니다.
# PI는 0.0753176 입니다.
# PI는 0.0753184 입니다.
# PI는 0.0753192 입니다.
# PI는 0.07532 입니다.
# PI는 0.0753208 입니다.
# PI는 0.0753216 입니다.
# PI는 0.0753224 입니다.
# PI는 0.0753232 입니다.
# PI는 0.075324 입니다.
# PI는 0.0753248 입니다.
# PI는 0.0753256 입니다.
# PI는 0.0753264 입니다.
# PI는 0.0753272 입니다.
# PI는 0.075328 입니다.
# PI는 0.0753288 입니다.
# PI는 0.0753296 입니다.
# PI는 0.0753304 입니다.
# PI는 0.0753312 입니다.
# PI는 0.075332 입니다.
# PI는 0.0753328 입니다.
# PI는 0.0753336 입니다.
# PI는 0.0753344 입니다.
# PI는 0.0753352 입니다.
# PI는 0.075336 입니다.
# PI는 0.0753368 입니다.
# PI는 0.0753376 입니다.
# PI는 0.0753384 입니다.
# PI는 0.0753392 입니다.
# PI는 0.07534 입니다.
# PI는 0.0753408 입니다.
# PI는 0.0753416 입니다.
# PI는 0.0753424 입니다.
# PI는 0.0753432 입니다.
# PI는 0.075344 입니다.
# PI는 0.0753448 입니다.
# PI는 0.0753456 입니다.
# PI는 0.0753464 입니다.
# PI는 0.0753472 입니다.
# PI는 0.075348 입니다.
# PI는 0.0753488 입니다.
# PI는 0.0753496 입니다.
# PI는 0.0753504 입니다.
# PI는 0.0753512 입니다.
# PI는 0.075352 입니다.
# PI는 0.0753528 입니다.
# PI는 0.0753536 입니다.
# PI는 0.0753544 입니다.
# PI는 0.0753552 입니다.
# PI는 0.075356 입니다.
# PI는 0.0753568 입니다.
# PI는 0.0753576 입니다.
# PI는 0.0753584 입니다.
# PI는 0.0753592 입니다.
# PI는 0.07536 입니다.
# PI는 0.0753608 입니다.
# PI는 0.0753616 입니다.
# PI는 0.0753624 입니다.
# PI는 0.0753632 입니다.
# PI는 0.075364 입니다.
# PI는 0.0753648 입니다.
# PI는 0.0753656 입니다.
# PI는 0.0753664 입니다.
# PI는 0.0753672 입니다.
# PI는 0.075368 입니다.
# PI는 0.0753688 입니다.
# PI는 0.0753696 입니다.
# PI는 0.0753704 입니다.
# PI는 0.0753712 입니다.
# PI는 0.075372 입니다.
# PI는 0.0753728 입니다.
# PI는 0.0753736 입니다.
# PI는 0.0753744 입니다.
# PI는 0.0753752 입니다.
# PI는 0.075376 입니다.
# PI는 0.0753768 입니다.
# PI는 0.0753776 입니다.
# PI는 0.0753784 입니다.
# PI는 0.0753792 입니다.
# PI는 0.07538 입니다.
# PI는 0.0753808 입니다.
# PI는 0.0753816 입니다.
# PI는 0.0753824 입니다.
# PI는 0.0753832 입니다.
# PI는 0.075384 입니다.
# PI는 0.0753848 입니다.
# PI는 0.0753856 입니다.
# PI는 0.0753864 입니다.
# PI는 0.0753872 입니다.
# PI는 0.075388 입니다.
# PI는 0.0753888 입니다.
# PI는 0.0753896 입니다.
# PI는 0.0753904 입니다.
# PI는 0.0753912 입니다.
# PI는 0.075392 입니다.
# PI는 0.0753928 입니다.
# PI는 0.0753936 입니다.
# PI는 0.0753944 입니다.
# PI는 0.0753952 입니다.
# PI는 0.075396 입니다.
# PI는 0.0753968 입니다.
# PI는 0.0753976 입니다.
# PI는 0.0753984 입니다.
# PI는 0.0753992 입니다.
# PI는 0.0754 입니다.
# PI는 0.0754008 입니다.
# PI는 0.0754016 입니다.
# PI는 0.0754024 입니다.
# PI는 0.0754032 입니다.
# PI는 0.075404 입니다.
# PI는 0.0754048 입니다.
# PI는 0.0754056 입니다.
# PI는 0.0754064 입니다.
# PI는 0.0754072 입니다.
# PI는 0.075408 입니다.
# PI는 0.0754088 입니다.
# PI는 0.0754096 입니다.
# PI는 0.0754104 입니다.
# PI는 0.0754112 입니다.
# PI는 0.075412 입니다.
# PI는 0.0754128 입니다.
# PI는 0.0754136 입니다.
# PI는 0.0754144 입니다.
# PI는 0.0754152 입니다.
# PI는 0.075416 입니다.
# PI는 0.0754168 입니다.
# PI는 0.0754176 입니다.
# PI는 0.0754184 입니다.
# PI는 0.0754192 입니다.
# PI는 0.07542 입니다.
# PI는 0.0754208 입니다.
# PI는 0.0754216 입니다.
# PI는 0.0754224 입니다.
# PI는 0.0754232 입니다.
# PI는 0.075424 입니다.
# PI는 0.0754248 입니다.
# PI는 0.0754256 입니다.
# PI는 0.0754264 입니다.
# PI는 0.0754272 입니다.
# PI는 0.075428 입니다.
# PI는 0.0754288 입니다.
# PI는 0.0754296 입니다.
# PI는 0.0754304 입니다.
# PI는 0.0754312 입니다.
# PI는 0.075432 입니다.
# PI는 0.0754328 입니다.
# PI는 0.0754336 입니다.
# PI는 0.0754344 입니다.
# PI는 0.0754352 입니다.
# PI는 0.075436 입니다.
# PI는 0.0754368 입니다.
# PI는 0.0754376 입니다.
# PI는 0.0754384 입니다.
# PI는 0.0754392 입니다.
# PI는 0.07544 입니다.
# PI는 0.0754408 입니다.
# PI는 0.0754416 입니다.
# PI는 0.0754424 입니다.
# PI는 0.0754432 입니다.
# PI는 0.075444 입니다.
# PI는 0.0754448 입니다.
# PI는 0.0754456 입니다.
# PI는 0.0754464 입니다.
# PI는 0.0754472 입니다.
# PI는 0.075448 입니다.
# PI는 0.0754488 입니다.
# PI는 0.0754496 입니다.
# PI는 0.0754504 입니다.
# PI는 0.0754512 입니다.
# PI는 0.075452 입니다.
# PI는 0.0754528 입니다.
# PI는 0.0754536 입니다.
# PI는 0.0754544 입니다.
# PI는 0.0754552 입니다.
# PI는 0.075456 입니다.
# PI는 0.0754568 입니다.
# PI는 0.0754576 입니다.
# PI는 0.0754584 입니다.
# PI는 0.0754592 입니다.
# PI는 0.07546 입니다.
# PI는 0.0754608 입니다.
# PI는 0.0754616 입니다.
# PI는 0.0754624 입니다.
# PI는 0.0754632 입니다.
# PI는 0.075464 입니다.
# PI는 0.0754648 입니다.
# PI는 0.0754656 입니다.
# PI는 0.0754664 입니다.
# PI는 0.0754672 입니다.
# PI는 0.075468 입니다.
# PI는 0.0754688 입니다.
# PI는 0.0754696 입니다.
# PI는 0.0754704 입니다.
# PI는 0.0754712 입니다.
# PI는 0.075472 입니다.
# PI는 0.0754728 입니다.
# PI는 0.0754736 입니다.
# PI는 0.0754744 입니다.
# PI는 0.0754752 입니다.
# PI는 0.075476 입니다.
# PI는 0.0754768 입니다.
# PI는 0.0754776 입니다.
# PI는 0.0754784 입니다.
# PI는 0.0754792 입니다.
# PI는 0.07548 입니다.
# PI는 0.0754808 입니다.
# PI는 0.0754816 입니다.
# PI는 0.0754824 입니다.
# PI는 0.0754832 입니다.
# PI는 0.075484 입니다.
# PI는 0.0754848 입니다.
# PI는 0.0754856 입니다.
# PI는 0.0754864 입니다.
# PI는 0.0754872 입니다.
# PI는 0.075488 입니다.
# PI는 0.0754888 입니다.
# PI는 0.0754896 입니다.
# PI는 0.0754904 입니다.
# PI는 0.0754912 입니다.
# PI는 0.075492 입니다.
# PI는 0.0754928 입니다.
# PI는 0.0754936 입니다.
# PI는 0.0754944 입니다.
# PI는 0.0754952 입니다.
# PI는 0.075496 입니다.
# PI는 0.0754968 입니다.
# PI는 0.0754976 입니다.
# PI는 0.0754984 입니다.
# PI는 0.0754992 입니다.
# PI는 0.0755 입니다.
# PI는 0.0755008 입니다.
# PI는 0.0755016 입니다.
# PI는 0.0755024 입니다.
# PI는 0.0755032 입니다.
# PI는 0.075504 입니다.
# PI는 0.0755048 입니다.
# PI는 0.0755056 입니다.
# PI는 0.0755064 입니다.
# PI는 0.0755072 입니다.
# PI는 0.075508 입니다.
# PI는 0.0755088 입니다.
# PI는 0.0755096 입니다.
# PI는 0.0755104 입니다.
# PI는 0.0755112 입니다.
# PI는 0.075512 입니다.
# PI는 0.0755128 입니다.
# PI는 0.0755136 입니다.
# PI는 0.0755144 입니다.
# PI는 0.0755152 입니다.
# PI는 0.075516 입니다.
# PI는 0.0755168 입니다.
# PI는 0.0755176 입니다.
# PI는 0.0755184 입니다.
# PI는 0.0755192 입니다.
# PI는 0.07552 입니다.
# PI는 0.0755208 입니다.
# PI는 0.0755216 입니다.
# PI는 0.0755224 입니다.
# PI는 0.0755232 입니다.
# PI는 0.075524 입니다.
# PI는 0.0755248 입니다.
# PI는 0.0755256 입니다.
# PI는 0.0755264 입니다.
# PI는 0.0755272 입니다.
# PI는 0.075528 입니다.
# PI는 0.0755288 입니다.
# PI는 0.0755296 입니다.
# PI는 0.0755304 입니다.
# PI는 0.0755312 입니다.
# PI는 0.075532 입니다.
# PI는 0.0755328 입니다.
# PI는 0.0755336 입니다.
# PI는 0.0755344 입니다.
# PI는 0.0755352 입니다.
# PI는 0.075536 입니다.
# PI는 0.0755368 입니다.
# PI는 0.0755376 입니다.
# PI는 0.0755384 입니다.
# PI는 0.0755392 입니다.
# PI는 0.07554 입니다.
# PI는 0.0755408 입니다.
# PI는 0.0755416 입니다.
# PI는 0.0755424 입니다.
# PI는 0.0755432 입니다.
# PI는 0.075544 입니다.
# PI는 0.0755448 입니다.
# PI는 0.0755456 입니다.
# PI는 0.0755464 입니다.
# PI는 0.0755472 입니다.
# PI는 0.075548 입니다.
# PI는 0.0755488 입니다.
# PI는 0.0755496 입니다.
# PI는 0.0755504 입니다.
# PI는 0.0755512 입니다.
# PI는 0.075552 입니다.
# PI는 0.0755528 입니다.
# PI는 0.0755536 입니다.
# PI는 0.0755544 입니다.
# PI는 0.0755552 입니다.
# PI는 0.075556 입니다.
# PI는 0.0755568 입니다.
# PI는 0.0755576 입니다.
# PI는 0.0755584 입니다.
# PI는 0.0755592 입니다.
# PI는 0.07556 입니다.
# PI는 0.0755608 입니다.
# PI는 0.0755616 입니다.
# PI는 0.0755624 입니다.
# PI는 0.0755632 입니다.
# PI는 0.075564 입니다.
# PI는 0.0755648 입니다.
# PI는 0.0755656 입니다.
# PI는 0.0755664 입니다.
# PI는 0.0755672 입니다.
# PI는 0.075568 입니다.
# PI는 0.0755688 입니다.
# PI는 0.0755696 입니다.
# PI는 0.0755704 입니다.
# PI는 0.0755712 입니다.
# PI는 0.075572 입니다.
# PI는 0.0755728 입니다.
# PI는 0.0755736 입니다.
# PI는 0.0755744 입니다.
# PI는 0.0755752 입니다.
# PI는 0.075576 입니다.
# PI는 0.0755768 입니다.
# PI는 0.0755776 입니다.
# PI는 0.0755784 입니다.
# PI는 0.0755792 입니다.
# PI는 0.07558 입니다.
# PI는 0.0755808 입니다.
# PI는 0.0755816 입니다.
# PI는 0.0755824 입니다.
# PI는 0.0755832 입니다.
# PI는 0.075584 입니다.
# PI는 0.0755848 입니다.
# PI는 0.0755856 입니다.
# PI는 0.0755864 입니다.
# PI는 0.0755872 입니다.
# PI는 0.075588 입니다.
# PI는 0.0755888 입니다.
# PI는 0.0755896 입니다.
# PI는 0.0755904 입니다.
# PI는 0.0755912 입니다.
# PI는 0.075592 입니다.
# PI는 0.0755928 입니다.
# PI는 0.0755936 입니다.
# PI는 0.0755944 입니다.
# PI는 0.0755952 입니다.
# PI는 0.075596 입니다.
# PI는 0.0755968 입니다.
# PI는 0.0755976 입니다.
# PI는 0.0755984 입니다.
# PI는 0.0755992 입니다.
# PI는 0.0756 입니다.
# PI는 0.0756008 입니다.
# PI는 0.0756016 입니다.
# PI는 0.0756024 입니다.
# PI는 0.0756032 입니다.
# PI는 0.075604 입니다.
# PI는 0.0756048 입니다.
# PI는 0.0756056 입니다.
# PI는 0.0756064 입니다.
# PI는 0.0756072 입니다.
# PI는 0.075608 입니다.
# PI는 0.0756088 입니다.
# PI는 0.0756096 입니다.
# PI는 0.0756104 입니다.
# PI는 0.0756112 입니다.
# PI는 0.075612 입니다.
# PI는 0.0756128 입니다.
# PI는 0.0756136 입니다.
# PI는 0.0756144 입니다.
# PI는 0.0756152 입니다.
# PI는 0.075616 입니다.
# PI는 0.0756168 입니다.
# PI는 0.0756176 입니다.
# PI는 0.0756184 입니다.
# PI는 0.0756192 입니다.
# PI는 0.07562 입니다.
# PI는 0.0756208 입니다.
# PI는 0.0756216 입니다.
# PI는 0.0756224 입니다.
# PI는 0.0756232 입니다.
# PI는 0.075624 입니다.
# PI는 0.0756248 입니다.
# PI는 0.0756256 입니다.
# PI는 0.0756264 입니다.
# PI는 0.0756272 입니다.
# PI는 0.075628 입니다.
# PI는 0.0756288 입니다.
# PI는 0.0756296 입니다.
# PI는 0.0756304 입니다.
# PI는 0.0756312 입니다.
# PI는 0.075632 입니다.
# PI는 0.0756328 입니다.
# PI는 0.0756336 입니다.
# PI는 0.0756344 입니다.
# PI는 0.0756352 입니다.
# PI는 0.075636 입니다.
# PI는 0.0756368 입니다.
# PI는 0.0756376 입니다.
# PI는 0.0756384 입니다.
# PI는 0.0756392 입니다.
# PI는 0.07564 입니다.
# PI는 0.0756408 입니다.
# PI는 0.0756416 입니다.
# PI는 0.0756424 입니다.
# PI는 0.0756432 입니다.
# PI는 0.075644 입니다.
# PI는 0.0756448 입니다.
# PI는 0.0756456 입니다.
# PI는 0.0756464 입니다.
# PI는 0.0756472 입니다.
# PI는 0.075648 입니다.
# PI는 0.0756488 입니다.
# PI는 0.0756496 입니다.
# PI는 0.0756504 입니다.
# PI는 0.0756512 입니다.
# PI는 0.075652 입니다.
# PI는 0.0756528 입니다.
# PI는 0.0756536 입니다.
# PI는 0.0756544 입니다.
# PI는 0.0756552 입니다.
# PI는 0.075656 입니다.
# PI는 0.0756568 입니다.
# PI는 0.0756576 입니다.
# PI는 0.0756584 입니다.
# PI는 0.0756592 입니다.
# PI는 0.07566 입니다.
# PI는 0.0756608 입니다.
# PI는 0.0756616 입니다.
# PI는 0.0756624 입니다.
# PI는 0.0756632 입니다.
# PI는 0.075664 입니다.
# PI는 0.0756648 입니다.
# PI는 0.0756656 입니다.
# PI는 0.0756664 입니다.
# PI는 0.0756672 입니다.
# PI는 0.075668 입니다.
# PI는 0.0756688 입니다.
# PI는 0.0756696 입니다.
# PI는 0.0756704 입니다.
# PI는 0.0756712 입니다.
# PI는 0.075672 입니다.
# PI는 0.0756728 입니다.
# PI는 0.0756736 입니다.
# PI는 0.0756744 입니다.
# PI는 0.0756752 입니다.
# PI는 0.075676 입니다.
# PI는 0.0756768 입니다.
# PI는 0.0756776 입니다.
# PI는 0.0756784 입니다.
# PI는 0.0756792 입니다.
# PI는 0.07568 입니다.
# PI는 0.0756808 입니다.
# PI는 0.0756816 입니다.
# PI는 0.0756824 입니다.
# PI는 0.0756832 입니다.
# PI는 0.075684 입니다.
# PI는 0.0756848 입니다.
# PI는 0.0756856 입니다.
# PI는 0.0756864 입니다.
# PI는 0.0756872 입니다.
# PI는 0.075688 입니다.
# PI는 0.0756888 입니다.
# PI는 0.0756896 입니다.
# PI는 0.0756904 입니다.
# PI는 0.0756912 입니다.
# PI는 0.075692 입니다.
# PI는 0.0756928 입니다.
# PI는 0.0756936 입니다.
# PI는 0.0756944 입니다.
# PI는 0.0756952 입니다.
# PI는 0.075696 입니다.
# PI는 0.0756968 입니다.
# PI는 0.0756976 입니다.
# PI는 0.0756984 입니다.
# PI는 0.0756992 입니다.
# PI는 0.0757 입니다.
# PI는 0.0757008 입니다.
# PI는 0.0757016 입니다.
# PI는 0.0757024 입니다.
# PI는 0.0757032 입니다.
# PI는 0.075704 입니다.
# PI는 0.0757048 입니다.
# PI는 0.0757056 입니다.
# PI는 0.0757064 입니다.
# PI는 0.0757072 입니다.
# PI는 0.075708 입니다.
# PI는 0.0757088 입니다.
# PI는 0.0757096 입니다.
# PI는 0.0757104 입니다.
# PI는 0.0757112 입니다.
# PI는 0.075712 입니다.
# PI는 0.0757128 입니다.
# PI는 0.0757136 입니다.
# PI는 0.0757144 입니다.
# PI는 0.0757152 입니다.
# PI는 0.075716 입니다.
# PI는 0.0757168 입니다.
# PI는 0.0757176 입니다.
# PI는 0.0757184 입니다.
# PI는 0.0757192 입니다.
# PI는 0.07572 입니다.
# PI는 0.0757208 입니다.
# PI는 0.0757216 입니다.
# PI는 0.0757224 입니다.
# PI는 0.0757232 입니다.
# PI는 0.075724 입니다.
# PI는 0.0757248 입니다.
# PI는 0.0757256 입니다.
# PI는 0.0757264 입니다.
# PI는 0.0757272 입니다.
# PI는 0.075728 입니다.
# PI는 0.0757288 입니다.
# PI는 0.0757296 입니다.
# PI는 0.0757304 입니다.
# PI는 0.0757312 입니다.
# PI는 0.075732 입니다.
# PI는 0.0757328 입니다.
# PI는 0.0757336 입니다.
# PI는 0.0757344 입니다.
# PI는 0.0757352 입니다.
# PI는 0.075736 입니다.
# PI는 0.0757368 입니다.
# PI는 0.0757376 입니다.
# PI는 0.0757384 입니다.
# PI는 0.0757392 입니다.
# PI는 0.07574 입니다.
# PI는 0.0757408 입니다.
# PI는 0.0757416 입니다.
# PI는 0.0757424 입니다.
# PI는 0.0757432 입니다.
# PI는 0.075744 입니다.
# PI는 0.0757448 입니다.
# PI는 0.0757456 입니다.
# PI는 0.0757464 입니다.
# PI는 0.0757472 입니다.
# PI는 0.075748 입니다.
# PI는 0.0757488 입니다.
# PI는 0.0757496 입니다.
# PI는 0.0757504 입니다.
# PI는 0.0757512 입니다.
# PI는 0.075752 입니다.
# PI는 0.0757528 입니다.
# PI는 0.0757536 입니다.
# PI는 0.0757544 입니다.
# PI는 0.0757552 입니다.
# PI는 0.075756 입니다.
# PI는 0.0757568 입니다.
# PI는 0.0757576 입니다.
# PI는 0.0757584 입니다.
# PI는 0.0757592 입니다.
# PI는 0.07576 입니다.
# PI는 0.0757608 입니다.
# PI는 0.0757616 입니다.
# PI는 0.0757624 입니다.
# PI는 0.0757632 입니다.
# PI는 0.075764 입니다.
# PI는 0.0757648 입니다.
# PI는 0.0757656 입니다.
# PI는 0.0757664 입니다.
# PI는 0.0757672 입니다.
# PI는 0.075768 입니다.
# PI는 0.0757688 입니다.
# PI는 0.0757696 입니다.
# PI는 0.0757704 입니다.
# PI는 0.0757712 입니다.
# PI는 0.075772 입니다.
# PI는 0.0757728 입니다.
# PI는 0.0757736 입니다.
# PI는 0.0757744 입니다.
# PI는 0.0757752 입니다.
# PI는 0.075776 입니다.
# PI는 0.0757768 입니다.
# PI는 0.0757776 입니다.
# PI는 0.0757784 입니다.
# PI는 0.0757792 입니다.
# PI는 0.07578 입니다.
# PI는 0.0757808 입니다.
# PI는 0.0757816 입니다.
# PI는 0.0757824 입니다.
# PI는 0.0757832 입니다.
# PI는 0.075784 입니다.
# PI는 0.0757848 입니다.
# PI는 0.0757856 입니다.
# PI는 0.0757864 입니다.
# PI는 0.0757872 입니다.
# PI는 0.075788 입니다.
# PI는 0.0757888 입니다.
# PI는 0.0757896 입니다.
# PI는 0.0757904 입니다.
# PI는 0.0757912 입니다.
# PI는 0.075792 입니다.
# PI는 0.0757928 입니다.
# PI는 0.0757936 입니다.
# PI는 0.0757944 입니다.
# PI는 0.0757952 입니다.
# PI는 0.075796 입니다.
# PI는 0.0757968 입니다.
# PI는 0.0757976 입니다.
# PI는 0.0757984 입니다.
# PI는 0.0757992 입니다.
# PI는 0.0758 입니다.
# PI는 0.0758008 입니다.
# PI는 0.0758016 입니다.
# PI는 0.0758024 입니다.
# PI는 0.0758032 입니다.
# PI는 0.075804 입니다.
# PI는 0.0758048 입니다.
# PI는 0.0758056 입니다.
# PI는 0.0758064 입니다.
# PI는 0.0758072 입니다.
# PI는 0.075808 입니다.
# PI는 0.0758088 입니다.
# PI는 0.0758096 입니다.
# PI는 0.0758104 입니다.
# PI는 0.0758112 입니다.
# PI는 0.075812 입니다.
# PI는 0.0758128 입니다.
# PI는 0.0758136 입니다.
# PI는 0.0758144 입니다.
# PI는 0.0758152 입니다.
# PI는 0.075816 입니다.
# PI는 0.0758168 입니다.
# PI는 0.0758176 입니다.
# PI는 0.0758184 입니다.
# PI는 0.0758192 입니다.
# PI는 0.07582 입니다.
# PI는 0.0758208 입니다.
# PI는 0.0758216 입니다.
# PI는 0.0758224 입니다.
# PI는 0.0758232 입니다.
# PI는 0.075824 입니다.
# PI는 0.0758248 입니다.
# PI는 0.0758256 입니다.
# PI는 0.0758264 입니다.
# PI는 0.0758272 입니다.
# PI는 0.075828 입니다.
# PI는 0.0758288 입니다.
# PI는 0.0758296 입니다.
# PI는 0.0758304 입니다.
# PI는 0.0758312 입니다.
# PI는 0.075832 입니다.
# PI는 0.0758328 입니다.
# PI는 0.0758336 입니다.
# PI는 0.0758344 입니다.
# PI는 0.0758352 입니다.
# PI는 0.075836 입니다.
# PI는 0.0758368 입니다.
# PI는 0.0758376 입니다.
# PI는 0.0758384 입니다.
# PI는 0.0758392 입니다.
# PI는 0.07584 입니다.
# PI는 0.0758408 입니다.
# PI는 0.0758416 입니다.
# PI는 0.0758424 입니다.
# PI는 0.0758432 입니다.
# PI는 0.075844 입니다.
# PI는 0.0758448 입니다.
# PI는 0.0758456 입니다.
# PI는 0.0758464 입니다.
# PI는 0.0758472 입니다.
# PI는 0.075848 입니다.
# PI는 0.0758488 입니다.
# PI는 0.0758496 입니다.
# PI는 0.0758504 입니다.
# PI는 0.0758512 입니다.
# PI는 0.075852 입니다.
# PI는 0.0758528 입니다.
# PI는 0.0758536 입니다.
# PI는 0.0758544 입니다.
# PI는 0.0758552 입니다.
# PI는 0.075856 입니다.
# PI는 0.0758568 입니다.
# PI는 0.0758576 입니다.
# PI는 0.0758584 입니다.
# PI는 0.0758592 입니다.
# PI는 0.07586 입니다.
# PI는 0.0758608 입니다.
# PI는 0.0758616 입니다.
# PI는 0.0758624 입니다.
# PI는 0.0758632 입니다.
# PI는 0.075864 입니다.
# PI는 0.0758648 입니다.
# PI는 0.0758656 입니다.
# PI는 0.0758664 입니다.
# PI는 0.0758672 입니다.
# PI는 0.075868 입니다.
# PI는 0.0758688 입니다.
# PI는 0.0758696 입니다.
# PI는 0.0758704 입니다.
# PI는 0.0758712 입니다.
# PI는 0.075872 입니다.
# PI는 0.0758728 입니다.
# PI는 0.0758736 입니다.
# PI는 0.0758744 입니다.
# PI는 0.0758752 입니다.
# PI는 0.075876 입니다.
# PI는 0.0758768 입니다.
# PI는 0.0758776 입니다.
# PI는 0.0758784 입니다.
# PI는 0.0758792 입니다.
# PI는 0.07588 입니다.
# PI는 0.0758808 입니다.
# PI는 0.0758816 입니다.
# PI는 0.0758824 입니다.
# PI는 0.0758832 입니다.
# PI는 0.075884 입니다.
# PI는 0.0758848 입니다.
# PI는 0.0758856 입니다.
# PI는 0.0758864 입니다.
# PI는 0.0758872 입니다.
# PI는 0.075888 입니다.
# PI는 0.0758888 입니다.
# PI는 0.0758896 입니다.
# PI는 0.0758904 입니다.
# PI는 0.0758912 입니다.
# PI는 0.075892 입니다.
# PI는 0.0758928 입니다.
# PI는 0.0758936 입니다.
# PI는 0.0758944 입니다.
# PI는 0.0758952 입니다.
# PI는 0.075896 입니다.
# PI는 0.0758968 입니다.
# PI는 0.0758976 입니다.
# PI는 0.0758984 입니다.
# PI는 0.0758992 입니다.
# PI는 0.0759 입니다.
# PI는 0.0759008 입니다.
# PI는 0.0759016 입니다.
# PI는 0.0759024 입니다.
# PI는 0.0759032 입니다.
# PI는 0.075904 입니다.
# PI는 0.0759048 입니다.
# PI는 0.0759056 입니다.
# PI는 0.0759064 입니다.
# PI는 0.0759072 입니다.
# PI는 0.075908 입니다.
# PI는 0.0759088 입니다.
# PI는 0.0759096 입니다.
# PI는 0.0759104 입니다.
# PI는 0.0759112 입니다.
# PI는 0.075912 입니다.
# PI는 0.0759128 입니다.
# PI는 0.0759136 입니다.
# PI는 0.0759144 입니다.
# PI는 0.0759152 입니다.
# PI는 0.075916 입니다.
# PI는 0.0759168 입니다.
# PI는 0.0759176 입니다.
# PI는 0.0759184 입니다.
# PI는 0.0759192 입니다.
# PI는 0.07592 입니다.
# PI는 0.0759208 입니다.
# PI는 0.0759216 입니다.
# PI는 0.0759224 입니다.
# PI는 0.0759232 입니다.
# PI는 0.075924 입니다.
# PI는 0.0759248 입니다.
# PI는 0.0759256 입니다.
# PI는 0.0759264 입니다.
# PI는 0.0759272 입니다.
# PI는 0.075928 입니다.
# PI는 0.0759288 입니다.
# PI는 0.0759296 입니다.
# PI는 0.0759304 입니다.
# PI는 0.0759312 입니다.
# PI는 0.075932 입니다.
# PI는 0.0759328 입니다.
# PI는 0.0759336 입니다.
# PI는 0.0759344 입니다.
# PI는 0.0759352 입니다.
# PI는 0.075936 입니다.
# PI는 0.0759368 입니다.
# PI는 0.0759376 입니다.
# PI는 0.0759384 입니다.
# PI는 0.0759392 입니다.
# PI는 0.07594 입니다.
# PI는 0.0759408 입니다.
# PI는 0.0759416 입니다.
# PI는 0.0759424 입니다.
# PI는 0.0759432 입니다.
# PI는 0.075944 입니다.
# PI는 0.0759448 입니다.
# PI는 0.0759456 입니다.
# PI는 0.0759464 입니다.
# PI는 0.0759472 입니다.
# PI는 0.075948 입니다.
# PI는 0.0759488 입니다.
# PI는 0.0759496 입니다.
# PI는 0.0759504 입니다.
# PI는 0.0759512 입니다.
# PI는 0.075952 입니다.
# PI는 0.0759528 입니다.
# PI는 0.0759536 입니다.
# PI는 0.0759544 입니다.
# PI는 0.0759552 입니다.
# PI는 0.075956 입니다.
# PI는 0.0759568 입니다.
# PI는 0.0759576 입니다.
# PI는 0.0759584 입니다.
# PI는 0.0759592 입니다.
# PI는 0.07596 입니다.
# PI는 0.0759608 입니다.
# PI는 0.0759616 입니다.
# PI는 0.0759624 입니다.
# PI는 0.0759632 입니다.
# PI는 0.075964 입니다.
# PI는 0.0759648 입니다.
# PI는 0.0759656 입니다.
# PI는 0.0759664 입니다.
# PI는 0.0759672 입니다.
# PI는 0.075968 입니다.
# PI는 0.0759688 입니다.
# PI는 0.0759696 입니다.
# PI는 0.0759704 입니다.
# PI는 0.0759712 입니다.
# PI는 0.075972 입니다.
# PI는 0.0759728 입니다.
# PI는 0.0759736 입니다.
# PI는 0.0759744 입니다.
# PI는 0.0759752 입니다.
# PI는 0.075976 입니다.
# PI는 0.0759768 입니다.
# PI는 0.0759776 입니다.
# PI는 0.0759784 입니다.
# PI는 0.0759792 입니다.
# PI는 0.07598 입니다.
# PI는 0.0759808 입니다.
# PI는 0.0759816 입니다.
# PI는 0.0759824 입니다.
# PI는 0.0759832 입니다.
# PI는 0.075984 입니다.
# PI는 0.0759848 입니다.
# PI는 0.0759856 입니다.
# PI는 0.0759864 입니다.
# PI는 0.0759872 입니다.
# PI는 0.075988 입니다.
# PI는 0.0759888 입니다.
# PI는 0.0759896 입니다.
# PI는 0.0759904 입니다.
# PI는 0.0759912 입니다.
# PI는 0.075992 입니다.
# PI는 0.0759928 입니다.
# PI는 0.0759936 입니다.
# PI는 0.0759944 입니다.
# PI는 0.0759952 입니다.
# PI는 0.075996 입니다.
# PI는 0.0759968 입니다.
# PI는 0.0759976 입니다.
# PI는 0.0759984 입니다.
# PI는 0.0759992 입니다.
# PI는 0.076 입니다.
# PI는 0.0760008 입니다.
# PI는 0.0760016 입니다.
# PI는 0.0760024 입니다.
# PI는 0.0760032 입니다.
# PI는 0.076004 입니다.
# PI는 0.0760048 입니다.
# PI는 0.0760056 입니다.
# PI는 0.0760064 입니다.
# PI는 0.0760072 입니다.
# PI는 0.076008 입니다.
# PI는 0.0760088 입니다.
# PI는 0.0760096 입니다.
# PI는 0.0760104 입니다.
# PI는 0.0760112 입니다.
# PI는 0.076012 입니다.
# PI는 0.0760128 입니다.
# PI는 0.0760136 입니다.
# PI는 0.0760144 입니다.
# PI는 0.0760152 입니다.
# PI는 0.076016 입니다.
# PI는 0.0760168 입니다.
# PI는 0.0760176 입니다.
# PI는 0.0760184 입니다.
# PI는 0.0760192 입니다.
# PI는 0.07602 입니다.
# PI는 0.0760208 입니다.
# PI는 0.0760216 입니다.
# PI는 0.0760224 입니다.
# PI는 0.0760232 입니다.
# PI는 0.076024 입니다.
# PI는 0.0760248 입니다.
# PI는 0.0760256 입니다.
# PI는 0.0760264 입니다.
# PI는 0.0760272 입니다.
# PI는 0.076028 입니다.
# PI는 0.0760288 입니다.
# PI는 0.0760296 입니다.
# PI는 0.0760304 입니다.
# PI는 0.0760312 입니다.
# PI는 0.076032 입니다.
# PI는 0.0760328 입니다.
# PI는 0.0760336 입니다.
# PI는 0.0760344 입니다.
# PI는 0.0760352 입니다.
# PI는 0.076036 입니다.
# PI는 0.0760368 입니다.
# PI는 0.0760376 입니다.
# PI는 0.0760384 입니다.
# PI는 0.0760392 입니다.
# PI는 0.07604 입니다.
# PI는 0.0760408 입니다.
# PI는 0.0760416 입니다.
# PI는 0.0760424 입니다.
# PI는 0.0760432 입니다.
# PI는 0.076044 입니다.
# PI는 0.0760448 입니다.
# PI는 0.0760456 입니다.
# PI는 0.0760464 입니다.
# PI는 0.0760472 입니다.
# PI는 0.076048 입니다.
# PI는 0.0760488 입니다.
# PI는 0.0760496 입니다.
# PI는 0.0760504 입니다.
# PI는 0.0760512 입니다.
# PI는 0.076052 입니다.
# PI는 0.0760528 입니다.
# PI는 0.0760536 입니다.
# PI는 0.0760544 입니다.
# PI는 0.0760552 입니다.
# PI는 0.076056 입니다.
# PI는 0.0760568 입니다.
# PI는 0.0760576 입니다.
# PI는 0.0760584 입니다.
# PI는 0.0760592 입니다.
# PI는 0.07606 입니다.
# PI는 0.0760608 입니다.
# PI는 0.0760616 입니다.
# PI는 0.0760624 입니다.
# PI는 0.0760632 입니다.
# PI는 0.076064 입니다.
# PI는 0.0760648 입니다.
# PI는 0.0760656 입니다.
# PI는 0.0760664 입니다.
# PI는 0.0760672 입니다.
# PI는 0.076068 입니다.
# PI는 0.0760688 입니다.
# PI는 0.0760696 입니다.
# PI는 0.0760704 입니다.
# PI는 0.0760712 입니다.
# PI는 0.076072 입니다.
# PI는 0.0760728 입니다.
# PI는 0.0760736 입니다.
# PI는 0.0760744 입니다.
# PI는 0.0760752 입니다.
# PI는 0.076076 입니다.
# PI는 0.0760768 입니다.
# PI는 0.0760776 입니다.
# PI는 0.0760784 입니다.
# PI는 0.0760792 입니다.
# PI는 0.07608 입니다.
# PI는 0.0760808 입니다.
# PI는 0.0760816 입니다.
# PI는 0.0760824 입니다.
# PI는 0.0760832 입니다.
# PI는 0.076084 입니다.
# PI는 0.0760848 입니다.
# PI는 0.0760856 입니다.
# PI는 0.0760864 입니다.
# PI는 0.0760872 입니다.
# PI는 0.076088 입니다.
# PI는 0.0760888 입니다.
# PI는 0.0760896 입니다.
# PI는 0.0760904 입니다.
# PI는 0.0760912 입니다.
# PI는 0.076092 입니다.
# PI는 0.0760928 입니다.
# PI는 0.0760936 입니다.
# PI는 0.0760944 입니다.
# PI는 0.0760952 입니다.
# PI는 0.076096 입니다.
# PI는 0.0760968 입니다.
# PI는 0.0760976 입니다.
# PI는 0.0760984 입니다.
# PI는 0.0760992 입니다.
# PI는 0.0761 입니다.
# PI는 0.0761008 입니다.
# PI는 0.0761016 입니다.
# PI는 0.0761024 입니다.
# PI는 0.0761032 입니다.
# PI는 0.076104 입니다.
# PI는 0.0761048 입니다.
# PI는 0.0761056 입니다.
# PI는 0.0761064 입니다.
# PI는 0.0761072 입니다.
# PI는 0.076108 입니다.
# PI는 0.0761088 입니다.
# PI는 0.0761096 입니다.
# PI는 0.0761104 입니다.
# PI는 0.0761112 입니다.
# PI는 0.076112 입니다.
# PI는 0.0761128 입니다.
# PI는 0.0761136 입니다.
# PI는 0.0761144 입니다.
# PI는 0.0761152 입니다.
# PI는 0.076116 입니다.
# PI는 0.0761168 입니다.
# PI는 0.0761176 입니다.
# PI는 0.0761184 입니다.
# PI는 0.0761192 입니다.
# PI는 0.07612 입니다.
# PI는 0.0761208 입니다.
# PI는 0.0761216 입니다.
# PI는 0.0761224 입니다.
# PI는 0.0761232 입니다.
# PI는 0.076124 입니다.
# PI는 0.0761248 입니다.
# PI는 0.0761256 입니다.
# PI는 0.0761264 입니다.
# PI는 0.0761272 입니다.
# PI는 0.076128 입니다.
# PI는 0.0761288 입니다.
# PI는 0.0761296 입니다.
# PI는 0.0761304 입니다.
# PI는 0.0761312 입니다.
# PI는 0.076132 입니다.
# PI는 0.0761328 입니다.
# PI는 0.0761336 입니다.
# PI는 0.0761344 입니다.
# PI는 0.0761352 입니다.
# PI는 0.076136 입니다.
# PI는 0.0761368 입니다.
# PI는 0.0761376 입니다.
# PI는 0.0761384 입니다.
# PI는 0.0761392 입니다.
# PI는 0.07614 입니다.
# PI는 0.0761408 입니다.
# PI는 0.0761416 입니다.
# PI는 0.0761424 입니다.
# PI는 0.0761432 입니다.
# PI는 0.076144 입니다.
# PI는 0.0761448 입니다.
# PI는 0.0761456 입니다.
# PI는 0.0761464 입니다.
# PI는 0.0761472 입니다.
# PI는 0.076148 입니다.
# PI는 0.0761488 입니다.
# PI는 0.0761496 입니다.
# PI는 0.0761504 입니다.
# PI는 0.0761512 입니다.
# PI는 0.076152 입니다.
# PI는 0.0761528 입니다.
# PI는 0.0761536 입니다.
# PI는 0.0761544 입니다.
# PI는 0.0761552 입니다.
# PI는 0.076156 입니다.
# PI는 0.0761568 입니다.
# PI는 0.0761576 입니다.
# PI는 0.0761584 입니다.
# PI는 0.0761592 입니다.
# PI는 0.07616 입니다.
# PI는 0.0761608 입니다.
# PI는 0.0761616 입니다.
# PI는 0.0761624 입니다.
# PI는 0.0761632 입니다.
# PI는 0.076164 입니다.
# PI는 0.0761648 입니다.
# PI는 0.0761656 입니다.
# PI는 0.0761664 입니다.
# PI는 0.0761672 입니다.
# PI는 0.076168 입니다.
# PI는 0.0761688 입니다.
# PI는 0.0761696 입니다.
# PI는 0.0761704 입니다.
# PI는 0.0761712 입니다.
# PI는 0.076172 입니다.
# PI는 0.0761728 입니다.
# PI는 0.0761736 입니다.
# PI는 0.0761744 입니다.
# PI는 0.0761752 입니다.
# PI는 0.076176 입니다.
# PI는 0.0761768 입니다.
# PI는 0.0761776 입니다.
# PI는 0.0761784 입니다.
# PI는 0.0761792 입니다.
# PI는 0.07618 입니다.
# PI는 0.0761808 입니다.
# PI는 0.0761816 입니다.
# PI는 0.0761824 입니다.
# PI는 0.0761832 입니다.
# PI는 0.076184 입니다.
# PI는 0.0761848 입니다.
# PI는 0.0761856 입니다.
# PI는 0.0761864 입니다.
# PI는 0.0761872 입니다.
# PI는 0.076188 입니다.
# PI는 0.0761888 입니다.
# PI는 0.0761896 입니다.
# PI는 0.0761904 입니다.
# PI는 0.0761912 입니다.
# PI는 0.076192 입니다.
# PI는 0.0761928 입니다.
# PI는 0.0761936 입니다.
# PI는 0.0761944 입니다.
# PI는 0.0761952 입니다.
# PI는 0.076196 입니다.
# PI는 0.0761968 입니다.
# PI는 0.0761976 입니다.
# PI는 0.0761984 입니다.
# PI는 0.0761992 입니다.
# PI는 0.0762 입니다.
# PI는 0.0762008 입니다.
# PI는 0.0762016 입니다.
# PI는 0.0762024 입니다.
# PI는 0.0762032 입니다.
# PI는 0.076204 입니다.
# PI는 0.0762048 입니다.
# PI는 0.0762056 입니다.
# PI는 0.0762064 입니다.
# PI는 0.0762072 입니다.
# PI는 0.076208 입니다.
# PI는 0.0762088 입니다.
# PI는 0.0762096 입니다.
# PI는 0.0762104 입니다.
# PI는 0.0762112 입니다.
# PI는 0.076212 입니다.
# PI는 0.0762128 입니다.
# PI는 0.0762136 입니다.
# PI는 0.0762144 입니다.
# PI는 0.0762152 입니다.
# PI는 0.076216 입니다.
# PI는 0.0762168 입니다.
# PI는 0.0762176 입니다.
# PI는 0.0762184 입니다.
# PI는 0.0762192 입니다.
# PI는 0.07622 입니다.
# PI는 0.0762208 입니다.
# PI는 0.0762216 입니다.
# PI는 0.0762224 입니다.
# PI는 0.0762232 입니다.
# PI는 0.076224 입니다.
# PI는 0.0762248 입니다.
# PI는 0.0762256 입니다.
# PI는 0.0762264 입니다.
# PI는 0.0762272 입니다.
# PI는 0.076228 입니다.
# PI는 0.0762288 입니다.
# PI는 0.0762296 입니다.
# PI는 0.0762304 입니다.
# PI는 0.0762312 입니다.
# PI는 0.076232 입니다.
# PI는 0.0762328 입니다.
# PI는 0.0762336 입니다.
# PI는 0.0762344 입니다.
# PI는 0.0762352 입니다.
# PI는 0.076236 입니다.
# PI는 0.0762368 입니다.
# PI는 0.0762376 입니다.
# PI는 0.0762384 입니다.
# PI는 0.0762392 입니다.
# PI는 0.07624 입니다.
# PI는 0.0762408 입니다.
# PI는 0.0762416 입니다.
# PI는 0.0762424 입니다.
# PI는 0.0762432 입니다.
# PI는 0.076244 입니다.
# PI는 0.0762448 입니다.
# PI는 0.0762456 입니다.
# PI는 0.0762464 입니다.
# PI는 0.0762472 입니다.
# PI는 0.076248 입니다.
# PI는 0.0762488 입니다.
# PI는 0.0762496 입니다.
# PI는 0.0762504 입니다.
# PI는 0.0762512 입니다.
# PI는 0.076252 입니다.
# PI는 0.0762528 입니다.
# PI는 0.0762536 입니다.
# PI는 0.0762544 입니다.
# PI는 0.0762552 입니다.
# PI는 0.076256 입니다.
# PI는 0.0762568 입니다.
# PI는 0.0762576 입니다.
# PI는 0.0762584 입니다.
# PI는 0.0762592 입니다.
# PI는 0.07626 입니다.
# PI는 0.0762608 입니다.
# PI는 0.0762616 입니다.
# PI는 0.0762624 입니다.
# PI는 0.0762632 입니다.
# PI는 0.076264 입니다.
# PI는 0.0762648 입니다.
# PI는 0.0762656 입니다.
# PI는 0.0762664 입니다.
# PI는 0.0762672 입니다.
# PI는 0.076268 입니다.
# PI는 0.0762688 입니다.
# PI는 0.0762696 입니다.
# PI는 0.0762704 입니다.
# PI는 0.0762712 입니다.
# PI는 0.076272 입니다.
# PI는 0.0762728 입니다.
# PI는 0.0762736 입니다.
# PI는 0.0762744 입니다.
# PI는 0.0762752 입니다.
# PI는 0.076276 입니다.
# PI는 0.0762768 입니다.
# PI는 0.0762776 입니다.
# PI는 0.0762784 입니다.
# PI는 0.0762792 입니다.
# PI는 0.07628 입니다.
# PI는 0.0762808 입니다.
# PI는 0.0762816 입니다.
# PI는 0.0762824 입니다.
# PI는 0.0762832 입니다.
# PI는 0.076284 입니다.
# PI는 0.0762848 입니다.
# PI는 0.0762856 입니다.
# PI는 0.0762864 입니다.
# PI는 0.0762872 입니다.
# PI는 0.076288 입니다.
# PI는 0.0762888 입니다.
# PI는 0.0762896 입니다.
# PI는 0.0762904 입니다.
# PI는 0.0762912 입니다.
# PI는 0.076292 입니다.
# PI는 0.0762928 입니다.
# PI는 0.0762936 입니다.
# PI는 0.0762944 입니다.
# PI는 0.0762952 입니다.
# PI는 0.076296 입니다.
# PI는 0.0762968 입니다.
# PI는 0.0762976 입니다.
# PI는 0.0762984 입니다.
# PI는 0.0762992 입니다.
# PI는 0.0763 입니다.
# PI는 0.0763008 입니다.
# PI는 0.0763016 입니다.
# PI는 0.0763024 입니다.
# PI는 0.0763032 입니다.
# PI는 0.076304 입니다.
# PI는 0.0763048 입니다.
# PI는 0.0763056 입니다.
# PI는 0.0763064 입니다.
# PI는 0.0763072 입니다.
# PI는 0.076308 입니다.
# PI는 0.0763088 입니다.
# PI는 0.0763096 입니다.
# PI는 0.0763104 입니다.
# PI는 0.0763112 입니다.
# PI는 0.076312 입니다.
# PI는 0.0763128 입니다.
# PI는 0.0763136 입니다.
# PI는 0.0763144 입니다.
# PI는 0.0763152 입니다.
# PI는 0.076316 입니다.
# PI는 0.0763168 입니다.
# PI는 0.0763176 입니다.
# PI는 0.0763184 입니다.
# PI는 0.0763192 입니다.
# PI는 0.07632 입니다.
# PI는 0.0763208 입니다.
# PI는 0.0763216 입니다.
# PI는 0.0763224 입니다.
# PI는 0.0763232 입니다.
# PI는 0.076324 입니다.
# PI는 0.0763248 입니다.
# PI는 0.0763256 입니다.
# PI는 0.0763264 입니다.
# PI는 0.0763272 입니다.
# PI는 0.076328 입니다.
# PI는 0.0763288 입니다.
# PI는 0.0763296 입니다.
# PI는 0.0763304 입니다.
# PI는 0.0763312 입니다.
# PI는 0.076332 입니다.
# PI는 0.0763328 입니다.
# PI는 0.0763336 입니다.
# PI는 0.0763344 입니다.
# PI는 0.0763352 입니다.
# PI는 0.076336 입니다.
# PI는 0.0763368 입니다.
# PI는 0.0763376 입니다.
# PI는 0.0763384 입니다.
# PI는 0.0763392 입니다.
# PI는 0.07634 입니다.
# PI는 0.0763408 입니다.
# PI는 0.0763416 입니다.
# PI는 0.0763424 입니다.
# PI는 0.0763432 입니다.
# PI는 0.076344 입니다.
# PI는 0.0763448 입니다.
# PI는 0.0763456 입니다.
# PI는 0.0763464 입니다.
# PI는 0.0763472 입니다.
# PI는 0.076348 입니다.
# PI는 0.0763488 입니다.
# PI는 0.0763496 입니다.
# PI는 0.0763504 입니다.
# PI는 0.0763512 입니다.
# PI는 0.076352 입니다.
# PI는 0.0763528 입니다.
# PI는 0.0763536 입니다.
# PI는 0.0763544 입니다.
# PI는 0.0763552 입니다.
# PI는 0.076356 입니다.
# PI는 0.0763568 입니다.
# PI는 0.0763576 입니다.
# PI는 0.0763584 입니다.
# PI는 0.0763592 입니다.
# PI는 0.07636 입니다.
# PI는 0.0763608 입니다.
# PI는 0.0763616 입니다.
# PI는 0.0763624 입니다.
# PI는 0.0763632 입니다.
# PI는 0.076364 입니다.
# PI는 0.0763648 입니다.
# PI는 0.0763656 입니다.
# PI는 0.0763664 입니다.
# PI는 0.0763672 입니다.
# PI는 0.076368 입니다.
# PI는 0.0763688 입니다.
# PI는 0.0763696 입니다.
# PI는 0.0763704 입니다.
# PI는 0.0763712 입니다.
# PI는 0.076372 입니다.
# PI는 0.0763728 입니다.
# PI는 0.0763736 입니다.
# PI는 0.0763744 입니다.
# PI는 0.0763752 입니다.
# PI는 0.076376 입니다.
# PI는 0.0763768 입니다.
# PI는 0.0763776 입니다.
# PI는 0.0763784 입니다.
# PI는 0.0763792 입니다.
# PI는 0.07638 입니다.
# PI는 0.0763808 입니다.
# PI는 0.0763816 입니다.
# PI는 0.0763824 입니다.
# PI는 0.0763832 입니다.
# PI는 0.076384 입니다.
# PI는 0.0763848 입니다.
# PI는 0.0763856 입니다.
# PI는 0.0763864 입니다.
# PI는 0.0763872 입니다.
# PI는 0.076388 입니다.
# PI는 0.0763888 입니다.
# PI는 0.0763896 입니다.
# PI는 0.0763904 입니다.
# PI는 0.0763912 입니다.
# PI는 0.076392 입니다.
# PI는 0.0763928 입니다.
# PI는 0.0763936 입니다.
# PI는 0.0763944 입니다.
# PI는 0.0763952 입니다.
# PI는 0.076396 입니다.
# PI는 0.0763968 입니다.
# PI는 0.0763976 입니다.
# PI는 0.0763984 입니다.
# PI는 0.0763992 입니다.
# PI는 0.0764 입니다.
# PI는 0.0764008 입니다.
# PI는 0.0764016 입니다.
# PI는 0.0764024 입니다.
# PI는 0.0764032 입니다.
# PI는 0.076404 입니다.
# PI는 0.0764048 입니다.
# PI는 0.0764056 입니다.
# PI는 0.0764064 입니다.
# PI는 0.0764072 입니다.
# PI는 0.076408 입니다.
# PI는 0.0764088 입니다.
# PI는 0.0764096 입니다.
# PI는 0.0764104 입니다.
# PI는 0.0764112 입니다.
# PI는 0.076412 입니다.
# PI는 0.0764128 입니다.
# PI는 0.0764136 입니다.
# PI는 0.0764144 입니다.
# PI는 0.0764152 입니다.
# PI는 0.076416 입니다.
# PI는 0.0764168 입니다.
# PI는 0.0764176 입니다.
# PI는 0.0764184 입니다.
# PI는 0.0764192 입니다.
# PI는 0.07642 입니다.
# PI는 0.0764208 입니다.
# PI는 0.0764216 입니다.
# PI는 0.0764224 입니다.
# PI는 0.0764232 입니다.
# PI는 0.076424 입니다.
# PI는 0.0764248 입니다.
# PI는 0.0764256 입니다.
# PI는 0.0764264 입니다.
# PI는 0.0764272 입니다.
# PI는 0.076428 입니다.
# PI는 0.0764288 입니다.
# PI는 0.0764296 입니다.
# PI는 0.0764304 입니다.
# PI는 0.0764312 입니다.
# PI는 0.076432 입니다.
# PI는 0.0764328 입니다.
# PI는 0.0764336 입니다.
# PI는 0.0764344 입니다.
# PI는 0.0764352 입니다.
# PI는 0.076436 입니다.
# PI는 0.0764368 입니다.
# PI는 0.0764376 입니다.
# PI는 0.0764384 입니다.
# PI는 0.0764392 입니다.
# PI는 0.07644 입니다.
# PI는 0.0764408 입니다.
# PI는 0.0764416 입니다.
# PI는 0.0764424 입니다.
# PI는 0.0764432 입니다.
# PI는 0.076444 입니다.
# PI는 0.0764448 입니다.
# PI는 0.0764456 입니다.
# PI는 0.0764464 입니다.
# PI는 0.0764472 입니다.
# PI는 0.076448 입니다.
# PI는 0.0764488 입니다.
# PI는 0.0764496 입니다.
# PI는 0.0764504 입니다.
# PI는 0.0764512 입니다.
# PI는 0.076452 입니다.
# PI는 0.0764528 입니다.
# PI는 0.0764536 입니다.
# PI는 0.0764544 입니다.
# PI는 0.0764552 입니다.
# PI는 0.076456 입니다.
# PI는 0.0764568 입니다.
# PI는 0.0764576 입니다.
# PI는 0.0764584 입니다.
# PI는 0.0764592 입니다.
# PI는 0.07646 입니다.
# PI는 0.0764608 입니다.
# PI는 0.0764616 입니다.
# PI는 0.0764624 입니다.
# PI는 0.0764632 입니다.
# PI는 0.076464 입니다.
# PI는 0.0764648 입니다.
# PI는 0.0764656 입니다.
# PI는 0.0764664 입니다.
# PI는 0.0764672 입니다.
# PI는 0.076468 입니다.
# PI는 0.0764688 입니다.
# PI는 0.0764696 입니다.
# PI는 0.0764704 입니다.
# PI는 0.0764712 입니다.
# PI는 0.076472 입니다.
# PI는 0.0764728 입니다.
# PI는 0.0764736 입니다.
# PI는 0.0764744 입니다.
# PI는 0.0764752 입니다.
# PI는 0.076476 입니다.
# PI는 0.0764768 입니다.
# PI는 0.0764776 입니다.
# PI는 0.0764784 입니다.
# PI는 0.0764792 입니다.
# PI는 0.07648 입니다.
# PI는 0.0764808 입니다.
# PI는 0.0764816 입니다.
# PI는 0.0764824 입니다.
# PI는 0.0764832 입니다.
# PI는 0.076484 입니다.
# PI는 0.0764848 입니다.
# PI는 0.0764856 입니다.
# PI는 0.0764864 입니다.
# PI는 0.0764872 입니다.
# PI는 0.076488 입니다.
# PI는 0.0764888 입니다.
# PI는 0.0764896 입니다.
# PI는 0.0764904 입니다.
# PI는 0.0764912 입니다.
# PI는 0.076492 입니다.
# PI는 0.0764928 입니다.
# PI는 0.0764936 입니다.
# PI는 0.0764944 입니다.
# PI는 0.0764952 입니다.
# PI는 0.076496 입니다.
# PI는 0.0764968 입니다.
# PI는 0.0764976 입니다.
# PI는 0.0764984 입니다.
# PI는 0.0764992 입니다.
# PI는 0.0765 입니다.
# PI는 0.0765008 입니다.
# PI는 0.0765016 입니다.
# PI는 0.0765024 입니다.
# PI는 0.0765032 입니다.
# PI는 0.076504 입니다.
# PI는 0.0765048 입니다.
# PI는 0.0765056 입니다.
# PI는 0.0765064 입니다.
# PI는 0.0765072 입니다.
# PI는 0.076508 입니다.
# PI는 0.0765088 입니다.
# PI는 0.0765096 입니다.
# PI는 0.0765104 입니다.
# PI는 0.0765112 입니다.
# PI는 0.076512 입니다.
# PI는 0.0765128 입니다.
# PI는 0.0765136 입니다.
# PI는 0.0765144 입니다.
# PI는 0.0765152 입니다.
# PI는 0.076516 입니다.
# PI는 0.0765168 입니다.
# PI는 0.0765176 입니다.
# PI는 0.0765184 입니다.
# PI는 0.0765192 입니다.
# PI는 0.07652 입니다.
# PI는 0.0765208 입니다.
# PI는 0.0765216 입니다.
# PI는 0.0765224 입니다.
# PI는 0.0765232 입니다.
# PI는 0.076524 입니다.
# PI는 0.0765248 입니다.
# PI는 0.0765256 입니다.
# PI는 0.0765264 입니다.
# PI는 0.0765272 입니다.
# PI는 0.076528 입니다.
# PI는 0.0765288 입니다.
# PI는 0.0765296 입니다.
# PI는 0.0765304 입니다.
# PI는 0.0765312 입니다.
# PI는 0.076532 입니다.
# PI는 0.0765328 입니다.
# PI는 0.0765336 입니다.
# PI는 0.0765344 입니다.
# PI는 0.0765352 입니다.
# PI는 0.076536 입니다.
# PI는 0.0765368 입니다.
# PI는 0.0765376 입니다.
# PI는 0.0765384 입니다.
# PI는 0.0765392 입니다.
# PI는 0.07654 입니다.
# PI는 0.0765408 입니다.
# PI는 0.0765416 입니다.
# PI는 0.0765424 입니다.
# PI는 0.0765432 입니다.
# PI는 0.076544 입니다.
# PI는 0.0765448 입니다.
# PI는 0.0765456 입니다.
# PI는 0.0765464 입니다.
# PI는 0.0765472 입니다.
# PI는 0.076548 입니다.
# PI는 0.0765488 입니다.
# PI는 0.0765496 입니다.
# PI는 0.0765504 입니다.
# PI는 0.0765512 입니다.
# PI는 0.076552 입니다.
# PI는 0.0765528 입니다.
# PI는 0.0765536 입니다.
# PI는 0.0765544 입니다.
# PI는 0.0765552 입니다.
# PI는 0.076556 입니다.
# PI는 0.0765568 입니다.
# PI는 0.0765576 입니다.
# PI는 0.0765584 입니다.
# PI는 0.0765592 입니다.
# PI는 0.07656 입니다.
# PI는 0.0765608 입니다.
# PI는 0.0765616 입니다.
# PI는 0.0765624 입니다.
# PI는 0.0765632 입니다.
# PI는 0.076564 입니다.
# PI는 0.0765648 입니다.
# PI는 0.0765656 입니다.
# PI는 0.0765664 입니다.
# PI는 0.0765672 입니다.
# PI는 0.076568 입니다.
# PI는 0.0765688 입니다.
# PI는 0.0765696 입니다.
# PI는 0.0765704 입니다.
# PI는 0.0765712 입니다.
# PI는 0.076572 입니다.
# PI는 0.0765728 입니다.
# PI는 0.0765736 입니다.
# PI는 0.0765744 입니다.
# PI는 0.0765752 입니다.
# PI는 0.076576 입니다.
# PI는 0.0765768 입니다.
# PI는 0.0765776 입니다.
# PI는 0.0765784 입니다.
# PI는 0.0765792 입니다.
# PI는 0.07658 입니다.
# PI는 0.0765808 입니다.
# PI는 0.0765816 입니다.
# PI는 0.0765824 입니다.
# PI는 0.0765832 입니다.
# PI는 0.076584 입니다.
# PI는 0.0765848 입니다.
# PI는 0.0765856 입니다.
# PI는 0.0765864 입니다.
# PI는 0.0765872 입니다.
# PI는 0.076588 입니다.
# PI는 0.0765888 입니다.
# PI는 0.0765896 입니다.
# PI는 0.0765904 입니다.
# PI는 0.0765912 입니다.
# PI는 0.076592 입니다.
# PI는 0.0765928 입니다.
# PI는 0.0765936 입니다.
# PI는 0.0765944 입니다.
# PI는 0.0765952 입니다.
# PI는 0.076596 입니다.
# PI는 0.0765968 입니다.
# PI는 0.0765976 입니다.
# PI는 0.0765984 입니다.
# PI는 0.0765992 입니다.
# PI는 0.0766 입니다.
# PI는 0.0766008 입니다.
# PI는 0.0766016 입니다.
# PI는 0.0766024 입니다.
# PI는 0.0766032 입니다.
# PI는 0.076604 입니다.
# PI는 0.0766048 입니다.
# PI는 0.0766056 입니다.
# PI는 0.0766064 입니다.
# PI는 0.0766072 입니다.
# PI는 0.076608 입니다.
# PI는 0.0766088 입니다.
# PI는 0.0766096 입니다.
# PI는 0.0766104 입니다.
# PI는 0.0766112 입니다.
# PI는 0.076612 입니다.
# PI는 0.0766128 입니다.
# PI는 0.0766136 입니다.
# PI는 0.0766144 입니다.
# PI는 0.0766152 입니다.
# PI는 0.076616 입니다.
# PI는 0.0766168 입니다.
# PI는 0.0766176 입니다.
# PI는 0.0766184 입니다.
# PI는 0.0766192 입니다.
# PI는 0.07662 입니다.
# PI는 0.0766208 입니다.
# PI는 0.0766216 입니다.
# PI는 0.0766224 입니다.
# PI는 0.0766232 입니다.
# PI는 0.076624 입니다.
# PI는 0.0766248 입니다.
# PI는 0.0766256 입니다.
# PI는 0.0766264 입니다.
# PI는 0.0766272 입니다.
# PI는 0.076628 입니다.
# PI는 0.0766288 입니다.
# PI는 0.0766296 입니다.
# PI는 0.0766304 입니다.
# PI는 0.0766312 입니다.
# PI는 0.076632 입니다.
# PI는 0.0766328 입니다.
# PI는 0.0766336 입니다.
# PI는 0.0766344 입니다.
# PI는 0.0766352 입니다.
# PI는 0.076636 입니다.
# PI는 0.0766368 입니다.
# PI는 0.0766376 입니다.
# PI는 0.0766384 입니다.
# PI는 0.0766392 입니다.
# PI는 0.07664 입니다.
# PI는 0.0766408 입니다.
# PI는 0.0766416 입니다.
# PI는 0.0766424 입니다.
# PI는 0.0766432 입니다.
# PI는 0.076644 입니다.
# PI는 0.0766448 입니다.
# PI는 0.0766456 입니다.
# PI는 0.0766464 입니다.
# PI는 0.0766472 입니다.
# PI는 0.076648 입니다.
# PI는 0.0766488 입니다.
# PI는 0.0766496 입니다.
# PI는 0.0766504 입니다.
# PI는 0.0766512 입니다.
# PI는 0.076652 입니다.
# PI는 0.0766528 입니다.
# PI는 0.0766536 입니다.
# PI는 0.0766544 입니다.
# PI는 0.0766552 입니다.
# PI는 0.076656 입니다.
# PI는 0.0766568 입니다.
# PI는 0.0766576 입니다.
# PI는 0.0766584 입니다.
# PI는 0.0766592 입니다.
# PI는 0.07666 입니다.
# PI는 0.0766608 입니다.
# PI는 0.0766616 입니다.
# PI는 0.0766624 입니다.
# PI는 0.0766632 입니다.
# PI는 0.076664 입니다.
# PI는 0.0766648 입니다.
# PI는 0.0766656 입니다.
# PI는 0.0766664 입니다.
# PI는 0.0766672 입니다.
# PI는 0.076668 입니다.
# PI는 0.0766688 입니다.
# PI는 0.0766696 입니다.
# PI는 0.0766704 입니다.
# PI는 0.0766712 입니다.
# PI는 0.076672 입니다.
# PI는 0.0766728 입니다.
# PI는 0.0766736 입니다.
# PI는 0.0766744 입니다.
# PI는 0.0766752 입니다.
# PI는 0.076676 입니다.
# PI는 0.0766768 입니다.
# PI는 0.0766776 입니다.
# PI는 0.0766784 입니다.
# PI는 0.0766792 입니다.
# PI는 0.07668 입니다.
# PI는 0.0766808 입니다.
# PI는 0.0766816 입니다.
# PI는 0.0766824 입니다.
# PI는 0.0766832 입니다.
# PI는 0.076684 입니다.
# PI는 0.0766848 입니다.
# PI는 0.0766856 입니다.
# PI는 0.0766864 입니다.
# PI는 0.0766872 입니다.
# PI는 0.076688 입니다.
# PI는 0.0766888 입니다.
# PI는 0.0766896 입니다.
# PI는 0.0766904 입니다.
# PI는 0.0766912 입니다.
# PI는 0.076692 입니다.
# PI는 0.0766928 입니다.
# PI는 0.0766936 입니다.
# PI는 0.0766944 입니다.
# PI는 0.0766952 입니다.
# PI는 0.076696 입니다.
# PI는 0.0766968 입니다.
# PI는 0.0766976 입니다.
# PI는 0.0766984 입니다.
# PI는 0.0766992 입니다.
# PI는 0.0767 입니다.
# PI는 0.0767008 입니다.
# PI는 0.0767016 입니다.
# PI는 0.0767024 입니다.
# PI는 0.0767032 입니다.
# PI는 0.076704 입니다.
# PI는 0.0767048 입니다.
# PI는 0.0767056 입니다.
# PI는 0.0767064 입니다.
# PI는 0.0767072 입니다.
# PI는 0.076708 입니다.
# PI는 0.0767088 입니다.
# PI는 0.0767096 입니다.
# PI는 0.0767104 입니다.
# PI는 0.0767112 입니다.
# PI는 0.076712 입니다.
# PI는 0.0767128 입니다.
# PI는 0.0767136 입니다.
# PI는 0.0767144 입니다.
# PI는 0.0767152 입니다.
# PI는 0.076716 입니다.
# PI는 0.0767168 입니다.
# PI는 0.0767176 입니다.
# PI는 0.0767184 입니다.
# PI는 0.0767192 입니다.
# PI는 0.07672 입니다.
# PI는 0.0767208 입니다.
# PI는 0.0767216 입니다.
# PI는 0.0767224 입니다.
# PI는 0.0767232 입니다.
# PI는 0.076724 입니다.
# PI는 0.0767248 입니다.
# PI는 0.0767256 입니다.
# PI는 0.0767264 입니다.
# PI는 0.0767272 입니다.
# PI는 0.076728 입니다.
# PI는 0.0767288 입니다.
# PI는 0.0767296 입니다.
# PI는 0.0767304 입니다.
# PI는 0.0767312 입니다.
# PI는 0.076732 입니다.
# PI는 0.0767328 입니다.
# PI는 0.0767336 입니다.
# PI는 0.0767344 입니다.
# PI는 0.0767352 입니다.
# PI는 0.076736 입니다.
# PI는 0.0767368 입니다.
# PI는 0.0767376 입니다.
# PI는 0.0767384 입니다.
# PI는 0.0767392 입니다.
# PI는 0.07674 입니다.
# PI는 0.0767408 입니다.
# PI는 0.0767416 입니다.
# PI는 0.0767424 입니다.
# PI는 0.0767432 입니다.
# PI는 0.076744 입니다.
# PI는 0.0767448 입니다.
# PI는 0.0767456 입니다.
# PI는 0.0767464 입니다.
# PI는 0.0767472 입니다.
# PI는 0.076748 입니다.
# PI는 0.0767488 입니다.
# PI는 0.0767496 입니다.
# PI는 0.0767504 입니다.
# PI는 0.0767512 입니다.
# PI는 0.076752 입니다.
# PI는 0.0767528 입니다.
# PI는 0.0767536 입니다.
# PI는 0.0767544 입니다.
# PI는 0.0767552 입니다.
# PI는 0.076756 입니다.
# PI는 0.0767568 입니다.
# PI는 0.0767576 입니다.
# PI는 0.0767584 입니다.
# PI는 0.0767592 입니다.
# PI는 0.07676 입니다.
# PI는 0.0767608 입니다.
# PI는 0.0767616 입니다.
# PI는 0.0767624 입니다.
# PI는 0.0767632 입니다.
# PI는 0.076764 입니다.
# PI는 0.0767648 입니다.
# PI는 0.0767656 입니다.
# PI는 0.0767664 입니다.
# PI는 0.0767672 입니다.
# PI는 0.076768 입니다.
# PI는 0.0767688 입니다.
# PI는 0.0767696 입니다.
# PI는 0.0767704 입니다.
# PI는 0.0767712 입니다.
# PI는 0.076772 입니다.
# PI는 0.0767728 입니다.
# PI는 0.0767736 입니다.
# PI는 0.0767744 입니다.
# PI는 0.0767752 입니다.
# PI는 0.076776 입니다.
# PI는 0.0767768 입니다.
# PI는 0.0767776 입니다.
# PI는 0.0767784 입니다.
# PI는 0.0767792 입니다.
# PI는 0.07678 입니다.
# PI는 0.0767808 입니다.
# PI는 0.0767816 입니다.
# PI는 0.0767824 입니다.
# PI는 0.0767832 입니다.
# PI는 0.076784 입니다.
# PI는 0.0767848 입니다.
# PI는 0.0767856 입니다.
# PI는 0.0767864 입니다.
# PI는 0.0767872 입니다.
# PI는 0.076788 입니다.
# PI는 0.0767888 입니다.
# PI는 0.0767896 입니다.
# PI는 0.0767904 입니다.
# PI는 0.0767912 입니다.
# PI는 0.076792 입니다.
# PI는 0.0767928 입니다.
# PI는 0.0767936 입니다.
# PI는 0.0767944 입니다.
# PI는 0.0767952 입니다.
# PI는 0.076796 입니다.
# PI는 0.0767968 입니다.
# PI는 0.0767976 입니다.
# PI는 0.0767984 입니다.
# PI는 0.0767992 입니다.
# PI는 0.0768 입니다.
# PI는 0.0768008 입니다.
# PI는 0.0768016 입니다.
# PI는 0.0768024 입니다.
# PI는 0.0768032 입니다.
# PI는 0.076804 입니다.
# PI는 0.0768048 입니다.
# PI는 0.0768056 입니다.
# PI는 0.0768064 입니다.
# PI는 0.0768072 입니다.
# PI는 0.076808 입니다.
# PI는 0.0768088 입니다.
# PI는 0.0768096 입니다.
# PI는 0.0768104 입니다.
# PI는 0.0768112 입니다.
# PI는 0.076812 입니다.
# PI는 0.0768128 입니다.
# PI는 0.0768136 입니다.
# PI는 0.0768144 입니다.
# PI는 0.0768152 입니다.
# PI는 0.076816 입니다.
# PI는 0.0768168 입니다.
# PI는 0.0768176 입니다.
# PI는 0.0768184 입니다.
# PI는 0.0768192 입니다.
# PI는 0.07682 입니다.
# PI는 0.0768208 입니다.
# PI는 0.0768216 입니다.
# PI는 0.0768224 입니다.
# PI는 0.0768232 입니다.
# PI는 0.076824 입니다.
# PI는 0.0768248 입니다.
# PI는 0.0768256 입니다.
# PI는 0.0768264 입니다.
# PI는 0.0768272 입니다.
# PI는 0.076828 입니다.
# PI는 0.0768288 입니다.
# PI는 0.0768296 입니다.
# PI는 0.0768304 입니다.
# PI는 0.0768312 입니다.
# PI는 0.076832 입니다.
# PI는 0.0768328 입니다.
# PI는 0.0768336 입니다.
# PI는 0.0768344 입니다.
# PI는 0.0768352 입니다.
# PI는 0.076836 입니다.
# PI는 0.0768368 입니다.
# PI는 0.0768376 입니다.
# PI는 0.0768384 입니다.
# PI는 0.0768392 입니다.
# PI는 0.07684 입니다.
# PI는 0.0768408 입니다.
# PI는 0.0768416 입니다.
# PI는 0.0768424 입니다.
# PI는 0.0768432 입니다.
# PI는 0.076844 입니다.
# PI는 0.0768448 입니다.
# PI는 0.0768456 입니다.
# PI는 0.0768464 입니다.
# PI는 0.0768472 입니다.
# PI는 0.076848 입니다.
# PI는 0.0768488 입니다.
# PI는 0.0768496 입니다.
# PI는 0.0768504 입니다.
# PI는 0.0768512 입니다.
# PI는 0.076852 입니다.
# PI는 0.0768528 입니다.
# PI는 0.0768536 입니다.
# PI는 0.0768544 입니다.
# PI는 0.0768552 입니다.
# PI는 0.076856 입니다.
# PI는 0.0768568 입니다.
# PI는 0.0768576 입니다.
# PI는 0.0768584 입니다.
# PI는 0.0768592 입니다.
# PI는 0.07686 입니다.
# PI는 0.0768608 입니다.
# PI는 0.0768616 입니다.
# PI는 0.0768624 입니다.
# PI는 0.0768632 입니다.
# PI는 0.076864 입니다.
# PI는 0.0768648 입니다.
# PI는 0.0768656 입니다.
# PI는 0.0768664 입니다.
# PI는 0.0768672 입니다.
# PI는 0.076868 입니다.
# PI는 0.0768688 입니다.
# PI는 0.0768696 입니다.
# PI는 0.0768704 입니다.
# PI는 0.0768712 입니다.
# PI는 0.076872 입니다.
# PI는 0.0768728 입니다.
# PI는 0.0768736 입니다.
# PI는 0.0768744 입니다.
# PI는 0.0768752 입니다.
# PI는 0.076876 입니다.
# PI는 0.0768768 입니다.
# PI는 0.0768776 입니다.
# PI는 0.0768784 입니다.
# PI는 0.0768792 입니다.
# PI는 0.07688 입니다.
# PI는 0.0768808 입니다.
# PI는 0.0768816 입니다.
# PI는 0.0768824 입니다.
# PI는 0.0768832 입니다.
# PI는 0.076884 입니다.
# PI는 0.0768848 입니다.
# PI는 0.0768856 입니다.
# PI는 0.0768864 입니다.
# PI는 0.0768872 입니다.
# PI는 0.076888 입니다.
# PI는 0.0768888 입니다.
# PI는 0.0768896 입니다.
# PI는 0.0768904 입니다.
# PI는 0.0768912 입니다.
# PI는 0.076892 입니다.
# PI는 0.0768928 입니다.
# PI는 0.0768936 입니다.
# PI는 0.0768944 입니다.
# ...
# PI는 0.07824 입니다.
# PI는 0.0782408 입니다.
# PI는 0.0782416 입니다.
# PI는 0.0782424 입니다.
# PI는 0.0782432 입니다.
# PI는 0.078244 입니다.
# PI는 0.0782448 입니다.
# PI는 0.0782456 입니다.
# PI는 0.0782464 입니다.
# PI는 0.0782472 입니다.
# PI는 0.078248 입니다.
# PI는 0.0782488 입니다.
# PI는 0.0782496 입니다.
# PI는 0.0782504 입니다.
# PI는 0.0782512 입니다.
# PI는 0.078252 입니다.
# PI는 0.0782528 입니다.
# PI는 0.0782536 입니다.
# PI는 0.0782544 입니다.
# PI는 0.0782552 입니다.
# PI는 0.078256 입니다.
# PI는 0.0782568 입니다.
# PI는 0.0782576 입니다.
# PI는 0.0782584 입니다.
# PI는 0.0782592 입니다.
# PI는 0.07826 입니다.
# PI는 0.0782608 입니다.
# PI는 0.0782616 입니다.
# PI는 0.0782624 입니다.
# PI는 0.0782632 입니다.
# PI는 0.078264 입니다.
# PI는 0.0782648 입니다.
# PI는 0.0782656 입니다.
# PI는 0.0782664 입니다.
# PI는 0.0782672 입니다.
# PI는 0.078268 입니다.
# PI는 0.0782688 입니다.
# PI는 0.0782696 입니다.
# PI는 0.0782704 입니다.
# PI는 0.0782712 입니다.
# PI는 0.078272 입니다.
# PI는 0.0782728 입니다.
# PI는 0.0782736 입니다.
# PI는 0.0782744 입니다.
# PI는 0.0782752 입니다.
# PI는 0.078276 입니다.
# PI는 0.0782768 입니다.
# PI는 0.0782776 입니다.
# PI는 0.0782784 입니다.
# PI는 0.0782792 입니다.
# PI는 0.07828 입니다.
# PI는 0.0782808 입니다.
# PI는 0.0782816 입니다.
# PI는 0.0782824 입니다.
# PI는 0.0782832 입니다.
# PI는 0.078284 입니다.
# PI는 0.0782848 입니다.
# PI는 0.0782856 입니다.
# PI는 0.0782864 입니다.
# PI는 0.0782872 입니다.
# PI는 0.078288 입니다.
# PI는 0.0782888 입니다.
# PI는 0.0782896 입니다.
# PI는 0.0782904 입니다.
# PI는 0.0782912 입니다.
# PI는 0.078292 입니다.
# PI는 0.0782928 입니다.
# PI는 0.0782936 입니다.
# PI는 0.0782944 입니다.
# PI는 0.0782952 입니다.
# PI는 0.078296 입니다.
# PI는 0.0782968 입니다.
# PI는 0.0782976 입니다.
# PI는 0.0782984 입니다.
# PI는 0.0782992 입니다.
# PI는 0.0783 입니다.
# PI는 0.0783008 입니다.
# PI는 0.0783016 입니다.
# PI는 0.0783024 입니다.
# PI는 0.0783032 입니다.
# PI는 0.078304 입니다.
# PI는 0.0783048 입니다.
# PI는 0.0783056 입니다.
# PI는 0.0783064 입니다.
# PI는 0.0783072 입니다.
# PI는 0.078308 입니다.
# PI는 0.0783088 입니다.
# PI는 0.0783096 입니다.
# PI는 0.0783104 입니다.
# PI는 0.0783112 입니다.
# PI는 0.078312 입니다.
# PI는 0.0783128 입니다.
# PI는 0.0783136 입니다.
# PI는 0.0783144 입니다.
# PI는 0.0783152 입니다.
# PI는 0.078316 입니다.
# PI는 0.0783168 입니다.
# PI는 0.0783176 입니다.
# PI는 0.0783184 입니다.
# PI는 0.0783192 입니다.
# PI는 0.07832 입니다.
# PI는 0.0783208 입니다.
# PI는 0.0783216 입니다.
# PI는 0.0783224 입니다.
# PI는 0.0783232 입니다.
# PI는 0.078324 입니다.
# PI는 0.0783248 입니다.
# PI는 0.0783256 입니다.
# PI는 0.0783264 입니다.
# PI는 0.0783272 입니다.
# PI는 0.078328 입니다.
# PI는 0.0783288 입니다.
# PI는 0.0783296 입니다.
# PI는 0.0783304 입니다.
# PI는 0.0783312 입니다.
# PI는 0.078332 입니다.
# PI는 0.0783328 입니다.
# PI는 0.0783336 입니다.
# PI는 0.0783344 입니다.
# PI는 0.0783352 입니다.
# PI는 0.078336 입니다.
# PI는 0.0783368 입니다.
# PI는 0.0783376 입니다.
# PI는 0.0783384 입니다.
# PI는 0.0783392 입니다.
# PI는 0.07834 입니다.
# PI는 0.0783408 입니다.
# PI는 0.0783416 입니다.
# PI는 0.0783424 입니다.
# PI는 0.0783432 입니다.
# PI는 0.078344 입니다.
# PI는 0.0783448 입니다.
# PI는 0.0783456 입니다.
# PI는 0.0783464 입니다.
# PI는 0.0783472 입니다.
# PI는 0.078348 입니다.
# PI는 0.0783488 입니다.
# PI는 0.0783496 입니다.
# PI는 0.0783504 입니다.
# PI는 0.0783512 입니다.
# PI는 0.078352 입니다.
# PI는 0.0783528 입니다.
# PI는 0.0783536 입니다.
# PI는 0.0783544 입니다.
# PI는 0.0783552 입니다.
# PI는 0.078356 입니다.
# PI는 0.0783568 입니다.
# PI는 0.0783576 입니다.
# PI는 0.0783584 입니다.
# PI는 0.0783592 입니다.
# PI는 0.07836 입니다.
# PI는 0.0783608 입니다.
# PI는 0.0783616 입니다.
# PI는 0.0783624 입니다.
# PI는 0.0783632 입니다.
# PI는 0.078364 입니다.
# PI는 0.0783648 입니다.
# PI는 0.0783656 입니다.
# PI는 0.0783664 입니다.
# PI는 0.0783672 입니다.
# PI는 0.078368 입니다.
# PI는 0.0783688 입니다.
# PI는 0.0783696 입니다.
# PI는 0.0783704 입니다.
# PI는 0.0783712 입니다.
# PI는 0.078372 입니다.
# PI는 0.0783728 입니다.
# PI는 0.0783736 입니다.
# PI는 0.0783744 입니다.
# PI는 0.0783752 입니다.
# PI는 0.078376 입니다.
# PI는 0.0783768 입니다.
# PI는 0.0783776 입니다.
# PI는 0.0783784 입니다.
# PI는 0.0783792 입니다.
# PI는 0.07838 입니다.
# PI는 0.0783808 입니다.
# PI는 0.0783816 입니다.
# PI는 0.0783824 입니다.
# PI는 0.0783832 입니다.
# PI는 0.078384 입니다.
# PI는 0.0783848 입니다.
# PI는 0.0783856 입니다.
# PI는 0.0783864 입니다.
# PI는 0.0783872 입니다.
# PI는 0.078388 입니다.
# PI는 0.0783888 입니다.
# PI는 0.0783896 입니다.
# PI는 0.0783904 입니다.
# PI는 0.0783912 입니다.
# PI는 0.078392 입니다.
# PI는 0.0783928 입니다.
# PI는 0.0783936 입니다.
# PI는 0.0783944 입니다.
# PI는 0.0783952 입니다.
# PI는 0.078396 입니다.
# PI는 0.0783968 입니다.
# PI는 0.0783976 입니다.
# PI는 0.0783984 입니다.
# PI는 0.0783992 입니다.
# PI는 0.0784 입니다.
# PI는 0.0784008 입니다.
# PI는 0.0784016 입니다.
# PI는 0.0784024 입니다.
# PI는 0.0784032 입니다.
# PI는 0.078404 입니다.
# PI는 0.0784048 입니다.
# PI는 0.0784056 입니다.
# PI는 0.0784064 입니다.
# PI는 0.0784072 입니다.
# PI는 0.078408 입니다.
# PI는 0.0784088 입니다.
# PI는 0.0784096 입니다.
# PI는 0.0784104 입니다.
# PI는 0.0784112 입니다.
# PI는 0.078412 입니다.
# PI는 0.0784128 입니다.
# PI는 0.0784136 입니다.
# PI는 0.0784144 입니다.
# PI는 0.0784152 입니다.
# PI는 0.078416 입니다.
# PI는 0.0784168 입니다.
# PI는 0.0784176 입니다.
# PI는 0.0784184 입니다.
# PI는 0.0784192 입니다.
# PI는 0.07842 입니다.
# PI는 0.0784208 입니다.
# PI는 0.0784216 입니다.
# PI는 0.0784224 입니다.
# PI는 0.0784232 입니다.
# PI는 0.078424 입니다.
# PI는 0.0784248 입니다.
# PI는 0.0784256 입니다.
# PI는 0.0784264 입니다.
# PI는 0.0784272 입니다.
# PI는 0.078428 입니다.
# PI는 0.0784288 입니다.
# PI는 0.0784296 입니다.
# PI는 0.0784304 입니다.
# PI는 0.0784312 입니다.
# PI는 0.078432 입니다.
# PI는 0.0784328 입니다.
# PI는 0.0784336 입니다.
# PI는 0.0784344 입니다.
# PI는 0.0784352 입니다.
# PI는 0.078436 입니다.
# PI는 0.0784368 입니다.
# PI는 0.0784376 입니다.
# PI는 0.0784384 입니다.
# PI는 0.0784392 입니다.
# PI는 0.07844 입니다.
# PI는 0.0784408 입니다.
# PI는 0.0784416 입니다.
# PI는 0.0784424 입니다.
# PI는 0.0784432 입니다.
# PI는 0.078444 입니다.
# PI는 0.0784448 입니다.
# PI는 0.0784456 입니다.
# PI는 0.0784464 입니다.
# PI는 0.0784472 입니다.
# PI는 0.078448 입니다.
# PI는 0.0784488 입니다.
# PI는 0.0784496 입니다.
# PI는 0.0784504 입니다.
# PI는 0.0784512 입니다.
# PI는 0.078452 입니다.
# PI는 0.0784528 입니다.
# PI는 0.0784536 입니다.
# PI는 0.0784544 입니다.
# PI는 0.0784552 입니다.
# PI는 0.078456 입니다.
# PI는 0.0784568 입니다.
# PI는 0.0784576 입니다.
# PI는 0.0784584 입니다.
# PI는 0.0784592 입니다.
# PI는 0.07846 입니다.
# PI는 0.0784608 입니다.
# PI는 0.0784616 입니다.
# PI는 0.0784624 입니다.
# PI는 0.0784632 입니다.
# PI는 0.078464 입니다.
# PI는 0.0784648 입니다.
# PI는 0.0784656 입니다.
# PI는 0.0784664 입니다.
# PI는 0.0784672 입니다.
# PI는 0.078468 입니다.
# PI는 0.0784688 입니다.
# PI는 0.0784696 입니다.
# PI는 0.0784704 입니다.
# PI는 0.0784712 입니다.
# PI는 0.078472 입니다.
# PI는 0.0784728 입니다.
# PI는 0.0784736 입니다.
# PI는 0.0784744 입니다.
# PI는 0.0784752 입니다.
# PI는 0.078476 입니다.
# PI는 0.0784768 입니다.
# PI는 0.0784776 입니다.
# PI는 0.0784784 입니다.
# PI는 0.0784792 입니다.
# PI는 0.07848 입니다.
# PI는 0.0784808 입니다.
# PI는 0.0784816 입니다.
# PI는 0.0784824 입니다.
# PI는 0.0784832 입니다.
# PI는 0.078484 입니다.
# PI는 0.0784848 입니다.
# PI는 0.0784856 입니다.
# PI는 0.0784864 입니다.
# PI는 0.0784872 입니다.
# PI는 0.078488 입니다.
# PI는 0.0784888 입니다.
# PI는 0.0784896 입니다.
# PI는 0.0784904 입니다.
# PI는 0.0784912 입니다.
# PI는 0.078492 입니다.
# PI는 0.0784928 입니다.
# PI는 0.0784936 입니다.
# PI는 0.0784944 입니다.
# PI는 0.0784952 입니다.
# PI는 0.078496 입니다.
# PI는 0.0784968 입니다.
# PI는 0.0784976 입니다.
# PI는 0.0784984 입니다.
# PI는 0.0784992 입니다.
# PI는 0.0785 입니다.
# PI는 0.0785008 입니다.
# PI는 0.0785016 입니다.
# PI는 0.0785024 입니다.
# PI는 0.0785032 입니다.
# PI는 0.078504 입니다.
# PI는 0.0785048 입니다.
# PI는 0.0785056 입니다.
# PI는 0.0785064 입니다.
# PI는 0.0785072 입니다.
# PI는 0.078508 입니다.
# PI는 0.0785088 입니다.
# PI는 0.0785096 입니다.
# PI는 0.0785104 입니다.
# PI는 0.0785112 입니다.
# PI는 0.078512 입니다.
# PI는 0.0785128 입니다.
# PI는 0.0785136 입니다.
# PI는 0.0785144 입니다.
# PI는 0.0785152 입니다.
# PI는 0.078516 입니다.
# PI는 0.0785168 입니다.
# PI는 0.0785176 입니다.
# PI는 0.0785184 입니다.
# PI는 0.0785192 입니다.
# PI는 0.07852 입니다.
# PI는 0.0785208 입니다.
# PI는 0.0785216 입니다.
# PI는 0.0785224 입니다.
# PI는 0.0785232 입니다.
# PI는 0.078524 입니다.
# PI는 0.0785248 입니다.
# PI는 0.0785256 입니다.
# PI는 0.0785264 입니다.
# PI는 0.0785272 입니다.
# PI는 0.078528 입니다.
# PI는 0.0785288 입니다.
# PI는 0.0785296 입니다.
# PI는 0.0785304 입니다.
# PI는 0.0785312 입니다.
# PI는 0.078532 입니다.
# PI는 0.0785328 입니다.
# PI는 0.0785336 입니다.
# PI는 0.0785344 입니다.
# PI는 0.0785352 입니다.
# PI는 0.078536 입니다.
# PI는 0.0785368 입니다.
# PI는 0.0785376 입니다.
# PI는 0.0785384 입니다.
# PI는 0.0785392 입니다.
# PI는 0.07854 입니다.
# PI는 0.0785408 입니다.
# PI는 0.0785416 입니다.
# PI는 0.0785424 입니다.
# PI는 0.0785432 입니다.
# PI는 0.078544 입니다.
# PI는 0.0785448 입니다.
# PI는 0.0785456 입니다.
# PI는 0.0785464 입니다.
# PI는 0.0785472 입니다.
# PI는 0.078548 입니다.
# PI는 0.0785488 입니다.
# PI는 0.0785496 입니다.
# PI는 0.0785504 입니다.
# PI는 0.0785512 입니다.
# PI는 0.078552 입니다.
# PI는 0.0785528 입니다.
# PI는 0.0785536 입니다.
# PI는 0.0785544 입니다.
# PI는 0.0785552 입니다.
# PI는 0.078556 입니다.
# PI는 0.0785568 입니다.
# PI는 0.0785576 입니다.
# PI는 0.0785584 입니다.
# PI는 0.0785592 입니다.
# PI는 0.07856 입니다.
# PI는 0.0785608 입니다.
# PI는 0.0785616 입니다.
# PI는 0.0785624 입니다.
# PI는 0.0785632 입니다.
# PI는 0.078564 입니다.
# PI는 0.0785648 입니다.
# PI는 0.0785656 입니다.
# PI는 0.0785664 입니다.
# PI는 0.0785672 입니다.
# PI는 0.078568 입니다.
# PI는 0.0785688 입니다.
# PI는 0.0785696 입니다.
# PI는 0.0785704 입니다.
# PI는 0.0785712 입니다.
# PI는 0.078572 입니다.
# PI는 0.0785728 입니다.
# PI는 0.0785736 입니다.
# PI는 0.0785744 입니다.
# PI는 0.0785752 입니다.
# PI는 0.078576 입니다.
# PI는 0.0785768 입니다.
# PI는 0.0785776 입니다.
# PI는 0.0785784 입니다.
# PI는 0.0785792 입니다.
# PI는 0.07858 입니다.
# PI는 0.0785808 입니다.
# PI는 0.0785816 입니다.
# PI는 0.0785824 입니다.
# PI는 0.0785832 입니다.
# PI는 0.078584 입니다.
# PI는 0.0785848 입니다.
# PI는 0.0785856 입니다.
# PI는 0.0785864 입니다.
# PI는 0.0785872 입니다.
# PI는 0.078588 입니다.
# PI는 0.0785888 입니다.
# PI는 0.0785896 입니다.
# PI는 0.0785904 입니다.
# PI는 0.0785912 입니다.
# PI는 0.078592 입니다.
# PI는 0.0785928 입니다.
# PI는 0.0785936 입니다.
# PI는 0.0785944 입니다.
# PI는 0.0785952 입니다.
# PI는 0.078596 입니다.
# PI는 0.0785968 입니다.
# PI는 0.0785976 입니다.
# PI는 0.0785984 입니다.
# PI는 0.0785992 입니다.
# PI는 0.0786 입니다.
# PI는 0.0786008 입니다.
# PI는 0.0786016 입니다.
# PI는 0.0786024 입니다.
# PI는 0.0786032 입니다.
# PI는 0.078604 입니다.
# PI는 0.0786048 입니다.
# PI는 0.0786056 입니다.
# PI는 0.0786064 입니다.
# PI는 0.0786072 입니다.
# PI는 0.078608 입니다.
# PI는 0.0786088 입니다.
# PI는 0.0786096 입니다.
# PI는 0.0786104 입니다.
# PI는 0.0786112 입니다.
# PI는 0.078612 입니다.
# PI는 0.0786128 입니다.
# PI는 0.0786136 입니다.
# PI는 0.0786144 입니다.
# PI는 0.0786152 입니다.
# PI는 0.078616 입니다.
# PI는 0.0786168 입니다.
# PI는 0.0786176 입니다.
# PI는 0.0786184 입니다.
# PI는 0.0786192 입니다.
# PI는 0.07862 입니다.
# PI는 0.0786208 입니다.
# PI는 0.0786216 입니다.
# PI는 0.0786224 입니다.
# PI는 0.0786232 입니다.
# PI는 0.078624 입니다.
# PI는 0.0786248 입니다.
# PI는 0.0786256 입니다.
# PI는 0.0786264 입니다.
# PI는 0.0786272 입니다.
# PI는 0.078628 입니다.
# PI는 0.0786288 입니다.
# PI는 0.0786296 입니다.
# PI는 0.0786304 입니다.
# PI는 0.0786312 입니다.
# PI는 0.078632 입니다.
# PI는 0.0786328 입니다.
# PI는 0.0786336 입니다.
# PI는 0.0786344 입니다.
# PI는 0.0786352 입니다.
# PI는 0.078636 입니다.
# PI는 0.0786368 입니다.
# PI는 0.0786376 입니다.
# PI는 0.0786384 입니다.
# PI는 0.0786392 입니다.
# PI는 0.07864 입니다.
# PI는 0.0786408 입니다.
# PI는 0.0786416 입니다.
# PI는 0.0786424 입니다.
# PI는 0.0786432 입니다.
# PI는 0.078644 입니다.
# PI는 0.0786448 입니다.
# PI는 0.0786456 입니다.
# PI는 0.0786464 입니다.
# PI는 0.0786472 입니다.
# PI는 0.078648 입니다.
# PI는 0.0786488 입니다.
# PI는 0.0786496 입니다.
# PI는 0.0786504 입니다.
# PI는 0.0786512 입니다.
# PI는 0.078652 입니다.
# PI는 0.0786528 입니다.
# PI는 0.0786536 입니다.
# PI는 0.0786544 입니다.
# PI는 0.0786552 입니다.
# PI는 0.078656 입니다.
# PI는 0.0786568 입니다.
# PI는 0.0786576 입니다.
# PI는 0.0786584 입니다.
# PI는 0.0786592 입니다.
# PI는 0.07866 입니다.
# PI는 0.0786608 입니다.
# PI는 0.0786616 입니다.
# PI는 0.0786624 입니다.
# PI는 0.0786632 입니다.
# PI는 0.078664 입니다.
# PI는 0.0786648 입니다.
# PI는 0.0786656 입니다.
# PI는 0.0786664 입니다.
# PI는 0.0786672 입니다.
# PI는 0.078668 입니다.
# PI는 0.0786688 입니다.
# PI는 0.0786696 입니다.
# PI는 0.0786704 입니다.
# PI는 0.0786712 입니다.
# PI는 0.078672 입니다.
# PI는 0.0786728 입니다.
# PI는 0.0786736 입니다.
# PI는 0.0786744 입니다.
# PI는 0.0786752 입니다.
# PI는 0.078676 입니다.
# PI는 0.0786768 입니다.
# PI는 0.0786776 입니다.
# PI는 0.0786784 입니다.
# PI는 0.0786792 입니다.
# PI는 0.07868 입니다.
# PI는 0.0786808 입니다.
# PI는 0.0786816 입니다.
# PI는 0.0786824 입니다.
# PI는 0.0786832 입니다.
# PI는 0.078684 입니다.
# PI는 0.0786848 입니다.
# PI는 0.0786856 입니다.
# PI는 0.0786864 입니다.
# PI는 0.0786872 입니다.
# PI는 0.078688 입니다.
# PI는 0.0786888 입니다.
# PI는 0.0786896 입니다.
# PI는 0.0786904 입니다.
# PI는 0.0786912 입니다.
# PI는 0.078692 입니다.
# PI는 0.0786928 입니다.
# PI는 0.0786936 입니다.
# PI는 0.0786944 입니다.
# PI는 0.0786952 입니다.
# PI는 0.078696 입니다.
# PI는 0.0786968 입니다.
# PI는 0.0786976 입니다.
# PI는 0.0786984 입니다.
# PI는 0.0786992 입니다.
# PI는 0.0787 입니다.
# PI는 0.0787008 입니다.
# PI는 0.0787016 입니다.
# PI는 0.0787024 입니다.
# PI는 0.0787032 입니다.
# PI는 0.078704 입니다.
# PI는 0.0787048 입니다.
# PI는 0.0787056 입니다.
# PI는 0.0787064 입니다.
# PI는 0.0787072 입니다.
# PI는 0.078708 입니다.
# PI는 0.0787088 입니다.
# PI는 0.0787096 입니다.
# PI는 0.0787104 입니다.
# PI는 0.0787112 입니다.
# PI는 0.078712 입니다.
# PI는 0.0787128 입니다.
# PI는 0.0787136 입니다.
# PI는 0.0787144 입니다.
# PI는 0.0787152 입니다.
# PI는 0.078716 입니다.
# PI는 0.0787168 입니다.
# PI는 0.0787176 입니다.
# PI는 0.0787184 입니다.
# PI는 0.0787192 입니다.
# PI는 0.07872 입니다.
# PI는 0.0787208 입니다.
# PI는 0.0787216 입니다.
# PI는 0.0787224 입니다.
# PI는 0.0787232 입니다.
# PI는 0.078724 입니다.
# PI는 0.0787248 입니다.
# PI는 0.0787256 입니다.
# PI는 0.0787264 입니다.
# PI는 0.0787272 입니다.
# PI는 0.078728 입니다.
# PI는 0.0787288 입니다.
# PI는 0.0787296 입니다.
# PI는 0.0787304 입니다.
# PI는 0.0787312 입니다.
# PI는 0.078732 입니다.
# PI는 0.0787328 입니다.
# PI는 0.0787336 입니다.
# PI는 0.0787344 입니다.
# PI는 0.0787352 입니다.
# PI는 0.078736 입니다.
# PI는 0.0787368 입니다.
# PI는 0.0787376 입니다.
# PI는 0.0787384 입니다.
# PI는 0.0787392 입니다.
# PI는 0.07874 입니다.
# PI는 0.0787408 입니다.
# PI는 0.0787416 입니다.
# PI는 0.0787424 입니다.
# PI는 0.0787432 입니다.
# PI는 0.078744 입니다.
# PI는 0.0787448 입니다.
# PI는 0.0787456 입니다.
# PI는 0.0787464 입니다.
# PI는 0.0787472 입니다.
# PI는 0.078748 입니다.
# PI는 0.0787488 입니다.
# PI는 0.0787496 입니다.
# PI는 0.0787504 입니다.
# PI는 0.0787512 입니다.
# PI는 0.078752 입니다.
# PI는 0.0787528 입니다.
# PI는 0.0787536 입니다.
# PI는 0.0787544 입니다.
# PI는 0.0787552 입니다.
# PI는 0.078756 입니다.
# PI는 0.0787568 입니다.
# PI는 0.0787576 입니다.
# PI는 0.0787584 입니다.
# PI는 0.0787592 입니다.
# PI는 0.07876 입니다.
# PI는 0.0787608 입니다.
# PI는 0.0787616 입니다.
# PI는 0.0787624 입니다.
# PI는 0.0787632 입니다.
# PI는 0.078764 입니다.
# PI는 0.0787648 입니다.
# PI는 0.0787656 입니다.
# PI는 0.0787664 입니다.
# PI는 0.0787672 입니다.
# PI는 0.078768 입니다.
# PI는 0.0787688 입니다.
# PI는 0.0787696 입니다.
# PI는 0.0787704 입니다.
# PI는 0.0787712 입니다.
# PI는 0.078772 입니다.
# PI는 0.0787728 입니다.
# PI는 0.0787736 입니다.
# PI는 0.0787744 입니다.
# PI는 0.0787752 입니다.
# PI는 0.078776 입니다.
# PI는 0.0787768 입니다.
# PI는 0.0787776 입니다.
# PI는 0.0787784 입니다.
# PI는 0.0787792 입니다.
# PI는 0.07878 입니다.
# PI는 0.0787808 입니다.
# PI는 0.0787816 입니다.
# PI는 0.0787824 입니다.
# PI는 0.0787832 입니다.
# PI는 0.078784 입니다.
# PI는 0.0787848 입니다.
# PI는 0.0787856 입니다.
# PI는 0.0787864 입니다.
# PI는 0.0787872 입니다.
# PI는 0.078788 입니다.
# PI는 0.0787888 입니다.
# PI는 0.0787896 입니다.
# PI는 0.0787904 입니다.
# PI는 0.0787912 입니다.
# PI는 0.078792 입니다.
# PI는 0.0787928 입니다.
# PI는 0.0787936 입니다.
# PI는 0.0787944 입니다.
# PI는 0.0787952 입니다.
# PI는 0.078796 입니다.
# PI는 0.0787968 입니다.
# PI는 0.0787976 입니다.
# PI는 0.0787984 입니다.
# PI는 0.0787992 입니다.
# PI는 0.0788 입니다.
# PI는 0.0788008 입니다.
# PI는 0.0788016 입니다.
# PI는 0.0788024 입니다.
# PI는 0.0788032 입니다.
# PI는 0.078804 입니다.
# PI는 0.0788048 입니다.
# PI는 0.0788056 입니다.
# PI는 0.0788064 입니다.
# PI는 0.0788072 입니다.
# PI는 0.078808 입니다.
# PI는 0.0788088 입니다.
# PI는 0.0788096 입니다.
# PI는 0.0788104 입니다.
# PI는 0.0788112 입니다.
# PI는 0.078812 입니다.
# PI는 0.0788128 입니다.
# PI는 0.0788136 입니다.
# PI는 0.0788144 입니다.
# PI는 0.0788152 입니다.
# PI는 0.078816 입니다.
# PI는 0.0788168 입니다.
# PI는 0.0788176 입니다.
# PI는 0.0788184 입니다.
# PI는 0.0788192 입니다.
# PI는 0.07882 입니다.
# PI는 0.0788208 입니다.
# PI는 0.0788216 입니다.
# PI는 0.0788224 입니다.
# PI는 0.0788232 입니다.
# PI는 0.078824 입니다.
# PI는 0.0788248 입니다.
# PI는 0.0788256 입니다.
# PI는 0.0788264 입니다.
# PI는 0.0788272 입니다.
# PI는 0.078828 입니다.
# PI는 0.0788288 입니다.
# PI는 0.0788296 입니다.
# PI는 0.0788304 입니다.
# PI는 0.0788312 입니다.
# PI는 0.078832 입니다.
# PI는 0.0788328 입니다.
# PI는 0.0788336 입니다.
# PI는 0.0788344 입니다.
# PI는 0.0788352 입니다.
# PI는 0.078836 입니다.
# PI는 0.0788368 입니다.
# PI는 0.0788376 입니다.
# PI는 0.0788384 입니다.
# PI는 0.0788392 입니다.
# PI는 0.07884 입니다.
# PI는 0.0788408 입니다.
# PI는 0.0788416 입니다.
# PI는 0.0788424 입니다.
# PI는 0.0788432 입니다.
# PI는 0.078844 입니다.
# PI는 0.0788448 입니다.
# PI는 0.0788456 입니다.
# PI는 0.0788464 입니다.
# PI는 0.0788472 입니다.
# PI는 0.078848 입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-2014f84be6b9> in <module>()
#       9     numberOfHits+=1
#      10     pi=4*numberOfHits/NUMBER_OF_TRIALS
# ---> 11     print("PI는",pi,"입니다.")
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
x=3
y=2
bool(x>y)
# Out:
# True

# %%
money=2000

# %%
if money>=3000:
  print("택시를 타고 가라")
else:
  print("걸어가라")
# Out:
# 걸어가라

# %%
pocket=['paper','money','cellphone']

# %%
if 'money' in pocket:
 pass
else:
    print("카드를 꺼내라")

# %%
pocket=['paper','handphone']

# %%
card=True

# %%
if 'money' in pocket:
    print("택시를 타고 가라")
else:
  if card:
      print("택시를 타고 가라")
  else:
      print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
pocket=['paper','cellphone']

# %%
card=True

# %%
if 'money' in pocket:
    print("택시를 타고 가라")
else:
  if card:
      print("택시를 타고 가라")
  else:
      print("걸어가라")
# Out:
# 택시를 타고 가라
